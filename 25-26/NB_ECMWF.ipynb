# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanZapa7a/AINavalEngineering/blob/main/NB_ECMWF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div class="output_png output_subarea output_execute_result">
# <center>
# <img src="data:image/png;base64,..." width="500px"/>
# </div>
#
# # 	Mean sea level pressure and wind at 200 hPa

# %% [markdown]
# This notebook will provide you guidance how to explore and plot ECMWF open dataset to produce the map from the ECMWF open charts web product.
# The original product can be found on this link: https://charts.ecmwf.int/products/medium-mslp-wind200

# %% [markdown]
# <div class="output_png output_subarea output_execute_result">
# <center>
# <img src="data:image/png;base64,..."/></center>
# </div>

# %% [markdown]
# The full list of available Open data products can be found [here](https://www.ecmwf.int/en/forecasts/datasets/open-data), and more information can be found in the [User documentation](https://confluence.ecmwf.int/display/DAC/ECMWF+open+data%3A+real-time+forecasts+from+IFS+and+AIFS).
#
# Access to ECMWF Open data is governed by the Creative Commons CC-BY-4.0 licence and associated [Terms of Use](https://apps.ecmwf.int/datasets/licences/general/).
#
# <sub> In applying this licence, ECMWF does not waive the privileges and immunities granted to it by virtue of its status as an intergovernmental organisation nor does it submit to any jurisdiction </sub>
#
# To find out how to obtain the access to the full forecast dataset at higher resolution please visit our [Access page](https://www.ecmwf.int/en/forecasts/accessing-forecasts).

# %% [markdown]
# ## Retrieve Data
# This product takes in input 3 parameters :
#
# * [Mean sea level pressure](https://codes.ecmwf.int/grib/param-db/151)
# * [U component of wind at 200 hPa](https://codes.ecmwf.int/grib/param-db/131)
# * [V component of wind  at 200 hPa](https://codes.ecmwf.int/grib/param-db/132)

# %% [markdown]
# In this example, we will use:
# - [**ecmwf.opendata**](https://github.com/ecmwf/ecmwf-opendata) Client to download the data
# - [**Metview**](https://metview.readthedocs.io/en/latest/) library to read, process and plot the data

# %% [markdown]
# First we need to install them in the current Jupyter kernel:
# <div class="alert alert-block alert-info">
# <b>Note:</b> If you are running the notebook on MyBinder or already have the libraries installed, go directly to importing the libraries.
# </div>
# <div class="alert alert-block alert-info">
# <b>Note:</b> If you don't have these libraries installed, click on three dots below, uncomment the code and run the next two cells.
# </div>

# %%
# !pip install -q condacolab
import condacolab
condacolab.install() # expect a kernel restart
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:11
# 🔁 Restarting kernel...

# %%
# !pip install ecmwf-opendata
# Out:
# Requirement already satisfied: ecmwf-opendata in /usr/local/lib/python3.11/site-packages (0.3.22)
# Requirement already satisfied: multiurl>=0.2.1 in /usr/local/lib/python3.11/site-packages (from ecmwf-opendata) (0.3.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/site-packages (from multiurl>=0.2.1->ecmwf-opendata) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/site-packages (from multiurl>=0.2.1->ecmwf-opendata) (4.67.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/site-packages (from multiurl>=0.2.1->ecmwf-opendata) (2025.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/site-packages (from multiurl>=0.2.1->ecmwf-opendata) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/site-packages (from python-dateutil->multiurl>=0.2.1->ecmwf-opendata) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests->multiurl>=0.2.1->ecmwf-opendata) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->multiurl>=0.2.1->ecmwf-opendata) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests->multiurl>=0.2.1->ecmwf-opendata) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->multiurl>=0.2.1->ecmwf-opendata) (2024.12.14)

# %%
# !conda install metview metview-python
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - metview
#     - metview-python
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alsa-lib-1.2.14            |       hb9d3cd8_0         553 KB  conda-forge
#     attr-2.5.1                 |       h166bdaf_1          69 KB  conda-forge
#     attrs-25.3.0               |     pyh71513ae_0          56 KB  conda-forge
#     bison-3.8.2                |       h59595ed_0         755 KB  conda-forge
#     blosc-1.21.6               |       he440d0b_1          47 KB  conda-forge
#     ca-certificates-2025.8.3   |       hbd8a1cb_0         151 KB  conda-forge
#     cairo-1.18.4               |       h3394656_0         955 KB  conda-forge
#     certifi-2025.8.3           |     pyhd8ed1ab_0         155 KB  conda-forge
#     cfgrib-0.9.15.0            |     pyhd8ed1ab_0          42 KB  conda-forge
#     click-8.2.1                |     pyh707e725_0          86 KB  conda-forge
#     conda-24.11.3              |  py311h38be061_0         1.1 MB  conda-forge
#     cyrus-sasl-2.1.28          |       hd9c7081_0         205 KB  conda-forge
#     dbus-1.13.6                |       h5008d03_3         604 KB  conda-forge
#     eccodes-2.41.0             |       h8bb6dbc_0         4.3 MB  conda-forge
#     expat-2.6.4                |       h5888daf_0         135 KB  conda-forge
#     fftw-3.3.10                |nompi_hf1063bd_110         2.0 MB  conda-forge
#     findlibs-0.1.2             |     pyhd8ed1ab_0          16 KB  conda-forge
#     flex-2.6.4                 |    h58526e2_1004         330 KB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_3         1.5 MB  conda-forge
#     fontconfig-2.15.0          |       h7e30c49_1         259 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     freeglut-3.2.2             |       ha6d2627_3         141 KB  conda-forge
#     freetype-2.13.3            |       ha770c72_1         168 KB  conda-forge
#     fribidi-1.0.10             |       h36c2ea0_0         112 KB  conda-forge
#     gdbm-1.18                  |       h0a1914f_2         190 KB  conda-forge
#     gettext-0.25.1             |       h5888daf_0         525 KB  conda-forge
#     gettext-tools-0.25.1       |       h5888daf_0         3.5 MB  conda-forge
#     glib-2.82.2                |       h07242d1_1         588 KB  conda-forge
#     glib-tools-2.82.2          |       h4833e2c_1         113 KB  conda-forge
#     graphite2-1.3.14           |       hecca717_1          97 KB  conda-forge
#     gst-plugins-base-1.24.7    |       h0a52356_0         2.7 MB  conda-forge
#     gstreamer-1.24.7           |       hf3bb09a_0         1.9 MB  conda-forge
#     harfbuzz-10.4.0            |       h76408a6_0         1.6 MB  conda-forge
#     hdf4-4.2.15                |       h2a13503_7         739 KB  conda-forge
#     hdf5-1.14.3                |nompi_h2d575fe_109         3.7 MB  conda-forge
#     icu-75.1                   |       he02047a_0        11.6 MB  conda-forge
#     jasper-4.2.8               |       he3c4edf_0         666 KB  conda-forge
#     lame-3.100                 |    h166bdaf_1003         496 KB  conda-forge
#     lerc-4.0.0                 |       h0aef613_1         258 KB  conda-forge
#     libaec-1.1.4               |       h3f801dc_0          36 KB  conda-forge
#     libasprintf-0.25.1         |       h8e693c7_0          52 KB  conda-forge
#     libasprintf-devel-0.25.1   |       h8e693c7_0          34 KB  conda-forge
#     libblas-3.9.0              |31_h59b9bed_openblas          16 KB  conda-forge
#     libcap-2.71                |       h39aace5_0         100 KB  conda-forge
#     libcblas-3.9.0             |31_he106b2a_openblas          16 KB  conda-forge
#     libclang-cpp19.1-19.1.7    |default_hb5137d0_3        19.6 MB  conda-forge
#     libclang13-19.1.7          |default_h9c6a7e4_3        11.3 MB  conda-forge
#     libcups-2.3.3              |       hb8b1518_5         4.3 MB  conda-forge
#     libdeflate-1.23            |       h86f0d12_0          71 KB  conda-forge
#     libdrm-2.4.125             |       hb9d3cd8_0         240 KB  conda-forge
#     libegl-1.7.0               |       ha4b6fd6_2          44 KB  conda-forge
#     libevent-2.1.12            |       hf998b51_1         417 KB  conda-forge
#     libflac-1.4.3              |       h59595ed_0         385 KB  conda-forge
#     libfreetype-2.13.3         |       ha770c72_1           8 KB  conda-forge
#     libfreetype6-2.13.3        |       h48d6fc4_1         371 KB  conda-forge
#     libgcrypt-lib-1.11.1       |       hb9d3cd8_0         577 KB  conda-forge
#     libgettextpo-0.25.1        |       h5888daf_0         174 KB  conda-forge
#     libgettextpo-devel-0.25.1  |       h5888daf_0          36 KB  conda-forge
#     libgfortran-14.2.0         |       h69a702a_2          52 KB  conda-forge
#     libgfortran-ng-14.2.0      |       h69a702a_2          53 KB  conda-forge
#     libgfortran5-14.2.0        |       hf1ad2bd_2         1.4 MB  conda-forge
#     libgl-1.7.0                |       ha4b6fd6_2         132 KB  conda-forge
#     libglib-2.82.2             |       h2ff4ddf_1         3.7 MB  conda-forge
#     libglu-9.0.3               |       h5888daf_1         318 KB  conda-forge
#     libglvnd-1.7.0             |       ha4b6fd6_2         129 KB  conda-forge
#     libglx-1.7.0               |       ha4b6fd6_2          74 KB  conda-forge
#     libgpg-error-1.55          |       h3f2d84a_0         305 KB  conda-forge
#     libjpeg-turbo-3.1.0        |       hb9d3cd8_0         614 KB  conda-forge
#     liblapack-3.9.0            |31_h7ac8fdf_openblas          16 KB  conda-forge
#     libllvm19-19.1.7           |       ha7bfdaf_1        38.3 MB  conda-forge
#     libnetcdf-4.9.2            |nompi_h00e09a9_116         815 KB  conda-forge
#     libntlm-1.8                |       hb9d3cd8_0          33 KB  conda-forge
#     libogg-1.3.5               |       hd0c01bc_1         213 KB  conda-forge
#     libopenblas-0.3.29         |pthreads_h94d23a6_0         5.6 MB  conda-forge
#     libopengl-1.7.0            |       ha4b6fd6_2          50 KB  conda-forge
#     libopus-1.5.2              |       hd0c01bc_0         305 KB  conda-forge
#     libpciaccess-0.18          |       hb9d3cd8_0          28 KB  conda-forge
#     libpng-1.6.50              |       h421ea60_1         310 KB  conda-forge
#     libpq-17.5                 |       h27ae623_0         2.6 MB  conda-forge
#     libsndfile-1.2.2           |       hc60ed4a_1         346 KB  conda-forge
#     libsystemd0-257.2          |       h3dc2cb9_0         476 KB  conda-forge
#     libtiff-4.7.0              |       hd9ff511_3         418 KB  conda-forge
#     libvorbis-1.3.7            |       h54a6638_2         279 KB  conda-forge
#     libwebp-base-1.6.0         |       hd42ef1d_0         419 KB  conda-forge
#     libxcb-1.17.0              |       h8a09558_0         387 KB  conda-forge
#     libxkbcommon-1.8.0         |       hc4a0caf_0         627 KB  conda-forge
#     libxml2-2.13.5             |       h8d12d68_1         674 KB  conda-forge
#     libzip-1.11.2              |       h6991a6a_0         106 KB  conda-forge
#     m4-1.4.20                  |       hb9d3cd8_0         280 KB  conda-forge
#     magics-metview-4.15.5      |       hee5ed45_0        25.7 MB  conda-forge
#     metview-5.23.0             |       h80ed381_0        40.5 MB  conda-forge
#     metview-python-1.16.1      |     pyhff2d567_1         372 KB  conda-forge
#     mpg123-1.32.9              |       hc50e24c_0         480 KB  conda-forge
#     mysql-common-9.0.1         |       h266115a_4         605 KB  conda-forge
#     mysql-libs-9.0.1           |       he0572af_4         1.3 MB  conda-forge
#     nspr-4.37                  |       h29cc59b_0         226 KB  conda-forge
#     nss-3.107                  |       hdf54f9c_0         1.9 MB  conda-forge
#     numpy-2.3.2                |  py311h2e04523_0         9.0 MB  conda-forge
#     openblas-0.3.29            |pthreads_h6ec200e_0         5.8 MB  conda-forge
#     openldap-2.6.10            |       he970967_0         762 KB  conda-forge
#     openssl-3.5.2              |       h26f9b46_0         3.0 MB  conda-forge
#     pandas-2.3.1               |  py311hed34c8f_0        14.7 MB  conda-forge
#     pango-1.56.3               |       h861ebed_0         444 KB  conda-forge
#     pcre2-10.44                |       hc749103_2         934 KB  conda-forge
#     pixman-0.46.4              |       h54a6638_1         440 KB  conda-forge
#     proj-9.5.1                 |       h0054346_0         3.0 MB  conda-forge
#     pthread-stubs-0.4          |    hb9d3cd8_1002           8 KB  conda-forge
#     pulseaudio-client-17.0     |       hb77b528_0         740 KB  conda-forge
#     python-dateutil-2.9.0.post0|     pyhe01879c_2         228 KB  conda-forge
#     python-eccodes-2.37.0      |  py311h9f3472d_0         104 KB  conda-forge
#     python-tzdata-2025.2       |     pyhd8ed1ab_0         141 KB  conda-forge
#     pytz-2025.2                |     pyhd8ed1ab_0         185 KB  conda-forge
#     pyyaml-6.0.2               |  py311h2dc5d0c_2         208 KB  conda-forge
#     qt-main-5.15.15            |       hc3cb62f_2        50.2 MB  conda-forge
#     simplejson-3.20.1          |  py311h9ecbd09_0         132 KB  conda-forge
#     six-1.17.0                 |     pyhe01879c_1          18 KB  conda-forge
#     snappy-1.2.2               |       h03e3b7b_0          45 KB  conda-forge
#     sqlite-3.47.2              |       h9eae976_0         864 KB  conda-forge
#     xarray-2025.7.1            |     pyhd8ed1ab_0         862 KB  conda-forge
#     xcb-util-0.4.1             |       h4f16b4b_2          20 KB  conda-forge
#     xcb-util-image-0.4.0       |       hb711507_2          24 KB  conda-forge
#     xcb-util-keysyms-0.4.1     |       hb711507_0          14 KB  conda-forge
#     xcb-util-renderutil-0.3.10 |       hb711507_0          17 KB  conda-forge
#     xcb-util-wm-0.4.2          |       hb711507_0          50 KB  conda-forge
#     xkeyboard-config-2.45      |       hb9d3cd8_0         383 KB  conda-forge
#     xorg-libice-1.1.2          |       hb9d3cd8_0          57 KB  conda-forge
#     xorg-libsm-1.2.6           |       he73a12e_0          27 KB  conda-forge
#     xorg-libx11-1.8.12         |       h4f16b4b_0         816 KB  conda-forge
#     xorg-libxau-1.0.12         |       hb9d3cd8_0          14 KB  conda-forge
#     xorg-libxdamage-1.1.6      |       hb9d3cd8_0          13 KB  conda-forge
#     xorg-libxdmcp-1.1.5        |       hb9d3cd8_0          19 KB  conda-forge
#     xorg-libxext-1.3.6         |       hb9d3cd8_0          49 KB  conda-forge
#     xorg-libxfixes-6.0.1       |       hb9d3cd8_0          19 KB  conda-forge
#     xorg-libxi-1.8.2           |       hb9d3cd8_0          46 KB  conda-forge
#     xorg-libxrender-0.9.12     |       hb9d3cd8_0          32 KB  conda-forge
#     xorg-libxxf86vm-1.1.6      |       hb9d3cd8_0          17 KB  conda-forge
#     yaml-0.2.5                 |       h280c20c_3          83 KB  conda-forge
#     zlib-1.3.1                 |       hb9d3cd8_2          90 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       304.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   alsa-lib           conda-forge/linux-64::alsa-lib-1.2.14-hb9d3cd8_0
#   attr               conda-forge/linux-64::attr-2.5.1-h166bdaf_1
#   attrs              conda-forge/noarch::attrs-25.3.0-pyh71513ae_0
#   bison              conda-forge/linux-64::bison-3.8.2-h59595ed_0
#   blosc              conda-forge/linux-64::blosc-1.21.6-he440d0b_1
#   cairo              conda-forge/linux-64::cairo-1.18.4-h3394656_0
#   cfgrib             conda-forge/noarch::cfgrib-0.9.15.0-pyhd8ed1ab_0
#   click              conda-forge/noarch::click-8.2.1-pyh707e725_0
#   cyrus-sasl         conda-forge/linux-64::cyrus-sasl-2.1.28-hd9c7081_0
#   dbus               conda-forge/linux-64::dbus-1.13.6-h5008d03_3
#   eccodes            conda-forge/linux-64::eccodes-2.41.0-h8bb6dbc_0
#   expat              conda-forge/linux-64::expat-2.6.4-h5888daf_0
#   fftw               conda-forge/linux-64::fftw-3.3.10-nompi_hf1063bd_110
#   findlibs           conda-forge/noarch::findlibs-0.1.2-pyhd8ed1ab_0
#   flex               conda-forge/linux-64::flex-2.6.4-h58526e2_1004
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
#   fontconfig         conda-forge/linux-64::fontconfig-2.15.0-h7e30c49_1
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   freeglut           conda-forge/linux-64::freeglut-3.2.2-ha6d2627_3
#   freetype           conda-forge/linux-64::freetype-2.13.3-ha770c72_1
#   fribidi            conda-forge/linux-64::fribidi-1.0.10-h36c2ea0_0
#   gdbm               conda-forge/linux-64::gdbm-1.18-h0a1914f_2
#   gettext            conda-forge/linux-64::gettext-0.25.1-h5888daf_0
#   gettext-tools      conda-forge/linux-64::gettext-tools-0.25.1-h5888daf_0
#   glib               conda-forge/linux-64::glib-2.82.2-h07242d1_1
#   glib-tools         conda-forge/linux-64::glib-tools-2.82.2-h4833e2c_1
#   graphite2          conda-forge/linux-64::graphite2-1.3.14-hecca717_1
#   gst-plugins-base   conda-forge/linux-64::gst-plugins-base-1.24.7-h0a52356_0
#   gstreamer          conda-forge/linux-64::gstreamer-1.24.7-hf3bb09a_0
#   harfbuzz           conda-forge/linux-64::harfbuzz-10.4.0-h76408a6_0
#   hdf4               conda-forge/linux-64::hdf4-4.2.15-h2a13503_7
#   hdf5               conda-forge/linux-64::hdf5-1.14.3-nompi_h2d575fe_109
#   icu                conda-forge/linux-64::icu-75.1-he02047a_0
#   jasper             conda-forge/linux-64::jasper-4.2.8-he3c4edf_0
#   lame               conda-forge/linux-64::lame-3.100-h166bdaf_1003
#   lerc               conda-forge/linux-64::lerc-4.0.0-h0aef613_1
#   libaec             conda-forge/linux-64::libaec-1.1.4-h3f801dc_0
#   libasprintf        conda-forge/linux-64::libasprintf-0.25.1-h8e693c7_0
#   libasprintf-devel  conda-forge/linux-64::libasprintf-devel-0.25.1-h8e693c7_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-31_h59b9bed_openblas
#   libcap             conda-forge/linux-64::libcap-2.71-h39aace5_0
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-31_he106b2a_openblas
#   libclang-cpp19.1   conda-forge/linux-64::libclang-cpp19.1-19.1.7-default_hb5137d0_3
#   libclang13         conda-forge/linux-64::libclang13-19.1.7-default_h9c6a7e4_3
#   libcups            conda-forge/linux-64::libcups-2.3.3-hb8b1518_5
#   libdeflate         conda-forge/linux-64::libdeflate-1.23-h86f0d12_0
#   libdrm             conda-forge/linux-64::libdrm-2.4.125-hb9d3cd8_0
#   libegl             conda-forge/linux-64::libegl-1.7.0-ha4b6fd6_2
#   libevent           conda-forge/linux-64::libevent-2.1.12-hf998b51_1
#   libflac            conda-forge/linux-64::libflac-1.4.3-h59595ed_0
#   libfreetype        conda-forge/linux-64::libfreetype-2.13.3-ha770c72_1
#   libfreetype6       conda-forge/linux-64::libfreetype6-2.13.3-h48d6fc4_1
#   libgcrypt-lib      conda-forge/linux-64::libgcrypt-lib-1.11.1-hb9d3cd8_0
#   libgettextpo       conda-forge/linux-64::libgettextpo-0.25.1-h5888daf_0
#   libgettextpo-devel conda-forge/linux-64::libgettextpo-devel-0.25.1-h5888daf_0
#   libgfortran        conda-forge/linux-64::libgfortran-14.2.0-h69a702a_2
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-14.2.0-h69a702a_2
#   libgfortran5       conda-forge/linux-64::libgfortran5-14.2.0-hf1ad2bd_2
#   libgl              conda-forge/linux-64::libgl-1.7.0-ha4b6fd6_2
#   libglib            conda-forge/linux-64::libglib-2.82.2-h2ff4ddf_1
#   libglu             conda-forge/linux-64::libglu-9.0.3-h5888daf_1
#   libglvnd           conda-forge/linux-64::libglvnd-1.7.0-ha4b6fd6_2
#   libglx             conda-forge/linux-64::libglx-1.7.0-ha4b6fd6_2
#   libgpg-error       conda-forge/linux-64::libgpg-error-1.55-h3f2d84a_0
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-3.1.0-hb9d3cd8_0
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-31_h7ac8fdf_openblas
#   libllvm19          conda-forge/linux-64::libllvm19-19.1.7-ha7bfdaf_1
#   libnetcdf          conda-forge/linux-64::libnetcdf-4.9.2-nompi_h00e09a9_116
#   libntlm            conda-forge/linux-64::libntlm-1.8-hb9d3cd8_0
#   libogg             conda-forge/linux-64::libogg-1.3.5-hd0c01bc_1
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.29-pthreads_h94d23a6_0
#   libopengl          conda-forge/linux-64::libopengl-1.7.0-ha4b6fd6_2
#   libopus            conda-forge/linux-64::libopus-1.5.2-hd0c01bc_0
#   libpciaccess       conda-forge/linux-64::libpciaccess-0.18-hb9d3cd8_0
#   libpng             conda-forge/linux-64::libpng-1.6.50-h421ea60_1
#   libpq              conda-forge/linux-64::libpq-17.5-h27ae623_0
#   libsndfile         conda-forge/linux-64::libsndfile-1.2.2-hc60ed4a_1
#   libsystemd0        conda-forge/linux-64::libsystemd0-257.2-h3dc2cb9_0
#   libtiff            conda-forge/linux-64::libtiff-4.7.0-hd9ff511_3
#   libvorbis          conda-forge/linux-64::libvorbis-1.3.7-h54a6638_2
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.6.0-hd42ef1d_0
#   libxcb             conda-forge/linux-64::libxcb-1.17.0-h8a09558_0
#   libxkbcommon       conda-forge/linux-64::libxkbcommon-1.8.0-hc4a0caf_0
#   libzip             conda-forge/linux-64::libzip-1.11.2-h6991a6a_0
#   m4                 conda-forge/linux-64::m4-1.4.20-hb9d3cd8_0
#   magics-metview     conda-forge/linux-64::magics-metview-4.15.5-hee5ed45_0
#   metview            conda-forge/linux-64::metview-5.23.0-h80ed381_0
#   metview-python     conda-forge/noarch::metview-python-1.16.1-pyhff2d567_1
#   mpg123             conda-forge/linux-64::mpg123-1.32.9-hc50e24c_0
#   mysql-common       conda-forge/linux-64::mysql-common-9.0.1-h266115a_4
#   mysql-libs         conda-forge/linux-64::mysql-libs-9.0.1-he0572af_4
#   nspr               conda-forge/linux-64::nspr-4.37-h29cc59b_0
#   nss                conda-forge/linux-64::nss-3.107-hdf54f9c_0
#   numpy              conda-forge/linux-64::numpy-2.3.2-py311h2e04523_0
#   openblas           conda-forge/linux-64::openblas-0.3.29-pthreads_h6ec200e_0
#   openldap           conda-forge/linux-64::openldap-2.6.10-he970967_0
#   pandas             conda-forge/linux-64::pandas-2.3.1-py311hed34c8f_0
#   pango              conda-forge/linux-64::pango-1.56.3-h861ebed_0
#   pcre2              conda-forge/linux-64::pcre2-10.44-hc749103_2
#   pixman             conda-forge/linux-64::pixman-0.46.4-h54a6638_1
#   proj               conda-forge/linux-64::proj-9.5.1-h0054346_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-hb9d3cd8_1002
#   pulseaudio-client  conda-forge/linux-64::pulseaudio-client-17.0-hb77b528_0
#   python-dateutil    conda-forge/noarch::python-dateutil-2.9.0.post0-pyhe01879c_2
#   python-eccodes     conda-forge/linux-64::python-eccodes-2.37.0-py311h9f3472d_0
#   python-tzdata      conda-forge/noarch::python-tzdata-2025.2-pyhd8ed1ab_0
#   pytz               conda-forge/noarch::pytz-2025.2-pyhd8ed1ab_0
#   pyyaml             conda-forge/linux-64::pyyaml-6.0.2-py311h2dc5d0c_2
#   qt-main            conda-forge/linux-64::qt-main-5.15.15-hc3cb62f_2
#   simplejson         conda-forge/linux-64::simplejson-3.20.1-py311h9ecbd09_0
#   six                conda-forge/noarch::six-1.17.0-pyhe01879c_1
#   snappy             conda-forge/linux-64::snappy-1.2.2-h03e3b7b_0
#   sqlite             conda-forge/linux-64::sqlite-3.47.2-h9eae976_0
#   xarray             conda-forge/noarch::xarray-2025.7.1-pyhd8ed1ab_0
#   xcb-util           conda-forge/linux-64::xcb-util-0.4.1-h4f16b4b_2
#   xcb-util-image     conda-forge/linux-64::xcb-util-image-0.4.0-hb711507_2
#   xcb-util-keysyms   conda-forge/linux-64::xcb-util-keysyms-0.4.1-hb711507_0
#   xcb-util-renderut~ conda-forge/linux-64::xcb-util-renderutil-0.3.10-hb711507_0
#   xcb-util-wm        conda-forge/linux-64::xcb-util-wm-0.4.2-hb711507_0
#   xkeyboard-config   conda-forge/linux-64::xkeyboard-config-2.45-hb9d3cd8_0
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.1.2-hb9d3cd8_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.6-he73a12e_0
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.8.12-h4f16b4b_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.12-hb9d3cd8_0
#   xorg-libxdamage    conda-forge/linux-64::xorg-libxdamage-1.1.6-hb9d3cd8_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.5-hb9d3cd8_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.6-hb9d3cd8_0
#   xorg-libxfixes     conda-forge/linux-64::xorg-libxfixes-6.0.1-hb9d3cd8_0
#   xorg-libxi         conda-forge/linux-64::xorg-libxi-1.8.2-hb9d3cd8_0
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.12-hb9d3cd8_0
#   xorg-libxxf86vm    conda-forge/linux-64::xorg-libxxf86vm-1.1.6-hb9d3cd8_0
#   yaml               conda-forge/linux-64::yaml-0.2.5-h280c20c_3
#   zlib               conda-forge/linux-64::zlib-1.3.1-hb9d3cd8_2
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge/linux-64::ca-certificates~ --> conda-forge/noarch::ca-certificates-2025.8.3-hbd8a1cb_0
#   certifi                           2024.12.14-pyhd8ed1ab_0 --> 2025.8.3-pyhd8ed1ab_0
#   conda                             24.11.2-py311h38be061_1 --> 24.11.3-py311h38be061_0
#   openssl                                  3.4.0-h7b32b05_1 --> 3.5.2-h26f9b46_0
#
# The following packages will be DOWNGRADED:
#
#   libxml2                                 2.13.5-h0d44e9d_1 --> 2.13.5-h8d12d68_1
#
#
#
# Downloading and Extracting Packages:
# qt-main-5.15.15      | 50.2 MB   | :   0% 0/1 [00:00<?, ?it/s]
# metview-5.23.0       | 40.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# libllvm19-19.1.7     | 38.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
# magics-metview-4.15. | 25.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# libclang-cpp19.1-19. | 19.6 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# pandas-2.3.1         | 14.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# icu-75.1             | 11.6 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# libclang13-19.1.7    | 11.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# numpy-2.3.2          | 9.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# openblas-0.3.29      | 5.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.29   | 5.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# eccodes-2.41.0       | 4.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# libcups-2.3.3        | 4.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gettext-tools-0.25.1 | 3.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.5.2        | 3.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# proj-9.5.1           | 3.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# metview-5.23.0       | 40.5 MB   | :   0% 0.0003862397560654541/1 [00:00<05:20, 321.04s/it]
#
#
# magics-metview-4.15. | 25.7 MB   | :   0% 0.0006083507201310805/1 [00:00<03:39, 219.68s/it]
#
# libllvm19-19.1.7     | 38.3 MB   | :   0% 0.00040813435890708774/1 [00:00<06:09, 369.29s/it]
#
#
#
# qt-main-5.15.15      | 50.2 MB   | :   0% 0.00031152966064125633/1 [00:00<10:18, 618.22s/it]
# metview-5.23.0       | 40.5 MB   | :   6% 0.06179836097047265/1 [00:00<00:02,  3.05s/it]
#
#
# magics-metview-4.15. | 25.7 MB   | :  12% 0.11923674114569179/1 [00:00<00:01,  1.63s/it]
#
# libllvm19-19.1.7     | 38.3 MB   | :   5% 0.049384257427757615/1 [00:00<00:03,  4.18s/it]
#
#
#
# qt-main-5.15.15      | 50.2 MB   | :   5% 0.049844745702601015/1 [00:00<00:04,  4.73s/it]
# metview-5.23.0       | 40.5 MB   | :  13% 0.13248023633045075/1 [00:00<00:01,  2.04s/it]
#
#
# magics-metview-4.15. | 25.7 MB   | :  23% 0.2281315200491552/1 [00:00<00:00,  1.23s/it]
#
# libllvm19-19.1.7     | 38.3 MB   | :  12% 0.12448097946666176/1 [00:00<00:01,  2.24s/it]
#
#
#
# qt-main-5.15.15      | 50.2 MB   | :  11% 0.11152761850956977/1 [00:00<00:02,  2.75s/it]
# metview-5.23.0       | 40.5 MB   | :  20% 0.1950510768130543/1 [00:00<00:01,  1.86s/it]
#
#
# magics-metview-4.15. | 25.7 MB   | :  33% 0.3309427917513078/1 [00:00<00:00,  1.12s/it]
#
# libllvm19-19.1.7     | 38.3 MB   | :  21% 0.20610785124807932/1 [00:00<00:01,  1.72s/it]
#
#
#
# qt-main-5.15.15      | 50.2 MB   | :  17% 0.17040672437076723/1 [00:00<00:01,  2.26s/it]
# metview-5.23.0       | 40.5 MB   | :  26% 0.25955311607598514/1 [00:00<00:01,  1.74s/it]
#
#
# magics-metview-4.15. | 25.7 MB   | :  45% 0.4520045850573929/1 [00:00<00:00,  1.00s/it]
#
# libllvm19-19.1.7     | 38.3 MB   | :  29% 0.2946730071309173/1 [00:00<00:01,  1.46s/it]
#
#
#
# qt-main-5.15.15      | 50.2 MB   | :  24% 0.2355164234447898/1 [00:00<00:01,  1.96s/it]
# metview-5.23.0       | 40.5 MB   | :  33% 0.3252138746071123/1 [00:00<00:01,  1.66s/it]
#
#
# magics-metview-4.15. | 25.7 MB   | :  57% 0.5706329754829536/1 [00:00<00:00,  1.06it/s]
#
# libllvm19-19.1.7     | 38.3 MB   | :  38% 0.3824218942959412/1 [00:00<00:00,  1.34s/it]
#
#
#
# qt-main-5.15.15      | 50.2 MB   | :  30% 0.3040529487858662/1 [00:00<00:01,  1.76s/it]
# metview-5.23.0       | 40.5 MB   | :  39% 0.39396455118676316/1 [00:00<00:00,  1.59s/it]
#
#
# magics-metview-4.15. | 25.7 MB   | :  70% 0.702036731031267/1 [00:00<00:00,  1.14it/s]
#
# libllvm19-19.1.7     | 38.3 MB   | :  51% 0.5105760829927668/1 [00:00<00:00,  1.09s/it]
#
#
#
# qt-main-5.15.15      | 50.2 MB   | :  36% 0.3638666436289874/1 [00:00<00:01,  1.89s/it]
# metview-5.23.0       | 40.5 MB   | :  51% 0.5106089575185303/1 [00:00<00:00,  1.31s/it]
#
# libllvm19-19.1.7     | 38.3 MB   | :  60% 0.6040388511824898/1 [00:00<00:00,  1.11s/it]
#
#
# qt-main-5.15.15      | 50.2 MB   | :  43% 0.43364928761262883/1 [00:00<00:00,  1.74s/it]
# metview-5.23.0       | 40.5 MB   | :  59% 0.5863119497073592/1 [00:00<00:00,  1.32s/it]
#
# libllvm19-19.1.7     | 38.3 MB   | :  70% 0.6958690819365846/1 [00:00<00:00,  1.17s/it]
#
#
# qt-main-5.15.15      | 50.2 MB   | :  51% 0.5065472282026828/1 [00:01<00:00,  1.61s/it]
# metview-5.23.0       | 40.5 MB   | :  67% 0.6697397370174973/1 [00:01<00:00,  1.28s/it]
#
# qt-main-5.15.15      | 50.2 MB   | :  59% 0.5922178848790283/1 [00:01<00:00,  1.45s/it]
# metview-5.23.0       | 40.5 MB   | :  75% 0.7473739279866536/1 [00:01<00:00,  1.29s/it]
#
# qt-main-5.15.15      | 50.2 MB   | :  66% 0.6629351178445935/1 [00:01<00:00,  1.46s/it]
#
#
#
# libclang-cpp19.1-19. | 19.6 MB   | : 100% 1.0/1 [00:01<00:00,  1.46it/s]
# metview-5.23.0       | 40.5 MB   | :  84% 0.8400714694423626/1 [00:01<00:00,  1.23s/it]
#
# libllvm19-19.1.7     | 38.3 MB   | :  99% 0.9917664921442232/1 [00:01<00:00,  1.09s/it]
#
#
#
#
# pandas-2.3.1         | 14.7 MB   | :   0% 0.001065997434032788/1 [00:01<20:29, 1230.35s/it]
# qt-main-5.15.15      | 50.2 MB   | :  73% 0.7327177618282349/1 [00:01<00:00,  1.58s/it]
#
#
#
#
# qt-main-5.15.15      | 50.2 MB   | :  81% 0.8084194693640602/1 [00:01<00:00,  1.51s/it]
#
#
#
#
# pandas-2.3.1         | 14.7 MB   | :  55% 0.5500546759609185/1 [00:01<00:00,  1.77s/it]
#
#
# qt-main-5.15.15      | 50.2 MB   | :  88% 0.8760214057232129/1 [00:01<00:00,  1.51s/it]
#
#
#
#
#
# icu-75.1             | 11.6 MB   | :   0% 0.00135078949540213/1 [00:01<19:37, 1178.77s/it]
#
#
#
#
# qt-main-5.15.15      | 50.2 MB   | :  96% 0.9573306471505808/1 [00:01<00:00,  1.43s/it]
#
#
#
#
#
# icu-75.1             | 11.6 MB   | :  28% 0.28366579403444725/1 [00:01<00:03,  4.29s/it]
#
#
#
#
# pandas-2.3.1         | 14.7 MB   | :  96% 0.9551337008933779/1 [00:01<00:00,  1.03s/it]
#
#
#
#
#
# icu-75.1             | 11.6 MB   | :  55% 0.5524729036194711/1 [00:01<00:00,  2.04s/it]
#
#
#
#
#
# icu-75.1             | 11.6 MB   | :  81% 0.8064213287550716/1 [00:01<00:00,  1.33s/it]
#
#
#
#
# pandas-2.3.1         | 14.7 MB   | : 100% 1.0/1 [00:02<00:00,  1.03s/it]
#
#
#
#
#
# icu-75.1             | 11.6 MB   | : 100% 1.0/1 [00:02<00:00,  1.33s/it]
#
# libllvm19-19.1.7     | 38.3 MB   | : 100% 1.0/1 [00:02<00:00,  1.09s/it]
#
#
#
#
#
#
# libclang13-19.1.7    | 11.3 MB   | :   0% 0.0013851128604060027/1 [00:02<26:46, 1608.29s/it]
#
#
#
#
#
#
#
# numpy-2.3.2          | 9.0 MB    | :   0% 0.001740123255190286/1 [00:02<21:30, 1292.36s/it]
#
#
#
#
#
#
#
#
# openblas-0.3.29      | 5.8 MB    | :   0% 0.0027063067485716486/1 [00:02<13:54, 836.91s/it]
#
#
#
#
#
#
# libclang13-19.1.7    | 11.3 MB   | :  27% 0.27425234636038853/1 [00:02<00:04,  6.06s/it]
#
#
#
#
#
#
#
# numpy-2.3.2          | 9.0 MB    | :  35% 0.3532450208036281/1 [00:02<00:03,  4.75s/it]
#
#
#
#
#
#
#
#
# openblas-0.3.29      | 5.8 MB    | :  47% 0.46548476075432355/1 [00:02<00:01,  3.63s/it]
# metview-5.23.0       | 40.5 MB   | : 100% 1.0/1 [00:02<00:00,  1.24s/it]
#
#
#
#
#
#
# libclang13-19.1.7    | 11.3 MB   | :  51% 0.508336419769003/1 [00:02<00:01,  2.97s/it]
#
#
#
#
#
#
#
# numpy-2.3.2          | 9.0 MB    | :  66% 0.6577665904619282/1 [00:02<00:00,  2.31s/it]
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.29   | 5.6 MB    | :   0% 0.0027679004637044184/1 [00:02<14:47, 889.59s/it]
#
#
#
#
#
#
#
#
# openblas-0.3.29      | 5.8 MB    | :  94% 0.939088441754362/1 [00:02<00:00,  1.61s/it]
#
#
#
#
#
#
# libclang13-19.1.7    | 11.3 MB   | :  70% 0.6994819945050313/1 [00:02<00:00,  2.02s/it]
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.29   | 5.6 MB    | :  50% 0.4982220834667953/1 [00:02<00:01,  3.67s/it]
#
#
#
#
#
#
#
# numpy-2.3.2          | 9.0 MB    | :  98% 0.9814295159273214/1 [00:02<00:00,  1.42s/it]
#
#
#
#
#
#
#
#
# openblas-0.3.29      | 5.8 MB    | : 100% 1.0/1 [00:02<00:00,  1.61s/it]
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.29   | 5.6 MB    | :  99% 0.9936762664698863/1 [00:02<00:00,  1.63s/it]
#
#
#
#
#
#
#
#
#
#
# eccodes-2.41.0       | 4.3 MB    | :   0% 0.003592437288025589/1 [00:02<12:44, 767.63s/it]
#
#
#
#
#
#
#
# numpy-2.3.2          | 9.0 MB    | : 100% 1.0/1 [00:02<00:00,  1.42s/it]
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.29   | 5.6 MB    | : 100% 1.0/1 [00:02<00:00,  1.63s/it]
#
#
#
#
#
#
#
#
#
#
#
# libcups-2.3.3        | 4.3 MB    | :   0% 0.0036218772527583545/1 [00:02<13:03, 786.00s/it]
#
#
#
#
#
#
#
#
#
#
# eccodes-2.41.0       | 4.3 MB    | :  64% 0.6394538372685549/1 [00:02<00:01,  3.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.7 MB    | :   0% 0.004168874001991818/1 [00:02<11:25, 688.21s/it]
#
#
#
#
#
#
# libclang13-19.1.7    | 11.3 MB   | : 100% 1.0/1 [00:02<00:00,  1.61s/it]
#
#
#
#
#
#
# qt-main-5.15.15      | 50.2 MB   | : 100% 1.0/1 [00:02<00:00,  1.43s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.7 MB    | :   0% 0.004175358960074659/1 [00:02<11:39, 702.55s/it]
#
#
#
#
#
#
#
#
#
#
#
# libcups-2.3.3        | 4.3 MB    | :  84% 0.8402755226399382/1 [00:02<00:00,  2.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.7 MB    | :  99% 0.9880231384720609/1 [00:02<00:00,  2.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gettext-tools-0.25.1 | 3.5 MB    | :   0% 0.004420763666416901/1 [00:02<11:12, 675.06s/it]
#
#
#
#
#
#
#
#
#
#
# eccodes-2.41.0       | 4.3 MB    | : 100% 1.0/1 [00:03<00:00,  3.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.7 MB    | :  84% 0.8350717920149318/1 [00:03<00:00,  2.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.7 MB    | : 100% 1.0/1 [00:03<00:00,  2.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.5.2        | 3.0 MB    | :   1% 0.005236433740607962/1 [00:03<09:49, 593.03s/it]
#
#
#
#
#
#
#
#
#
#
#
# libcups-2.3.3        | 4.3 MB    | : 100% 1.0/1 [00:03<00:00,  2.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.7 MB    | : 100% 1.0/1 [00:03<00:00,  2.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# proj-9.5.1           | 3.0 MB    | :   1% 0.005270283789213096/1 [00:03<09:55, 598.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.7 MB    | :   1% 0.005805033911120339/1 [00:03<09:03, 546.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gettext-tools-0.25.1 | 3.5 MB    | : 100% 1.0/1 [00:03<00:00,  2.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gettext-tools-0.25.1 | 3.5 MB    | : 100% 1.0/1 [00:03<00:00,  2.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.5.2        | 3.0 MB    | : 100% 1.0/1 [00:03<00:00,  2.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.5.2        | 3.0 MB    | : 100% 1.0/1 [00:03<00:00,  2.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# proj-9.5.1           | 3.0 MB    | : 100% 1.0/1 [00:03<00:00,  2.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# proj-9.5.1           | 3.0 MB    | : 100% 1.0/1 [00:03<00:00,  2.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.7 MB    | : 100% 1.0/1 [00:03<00:00,  2.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.7 MB    | : 100% 1.0/1 [00:03<00:00,  2.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# libclang-cpp19.1-19. | 19.6 MB   | : 100% 1.0/1 [00:04<00:00,  1.46it/s]
#
#
# magics-metview-4.15. | 25.7 MB   | : 100% 1.0/1 [00:06<00:00,  1.08it/s]
#
#
#
#
#
# icu-75.1             | 11.6 MB   | : 100% 1.0/1 [00:07<00:00,  1.33s/it]
#
#
#
#
# pandas-2.3.1         | 14.7 MB   | : 100% 1.0/1 [00:08<00:00,  1.03s/it]
#
# libllvm19-19.1.7     | 38.3 MB   | : 100% 1.0/1 [00:11<00:00,  1.09s/it]
#
#
#
#
#
#
#
#
# openblas-0.3.29      | 5.8 MB    | : 100% 1.0/1 [00:11<00:00,  1.61s/it]
#
#
#
#
#
#
#
# numpy-2.3.2          | 9.0 MB    | : 100% 1.0/1 [00:13<00:00,  1.42s/it]
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.29   | 5.6 MB    | : 100% 1.0/1 [00:13<00:00,  1.63s/it]
#
#
#
#
#
#
# libclang13-19.1.7    | 11.3 MB   | : 100% 1.0/1 [00:14<00:00,  1.61s/it]
# qt-main-5.15.15      | 50.2 MB   | : 100% 1.0/1 [00:28<00:00,  1.43s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.7 MB    | : 100% 1.0/1 [00:28<00:00,  2.14s/it]
#
#
#
#
#
#
#
#
#
#
#
# libcups-2.3.3        | 4.3 MB    | : 100% 1.0/1 [00:28<00:00,  2.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.7 MB    | : 100% 1.0/1 [00:29<00:00,  2.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gettext-tools-0.25.1 | 3.5 MB    | : 100% 1.0/1 [00:29<00:00,  2.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.5.2        | 3.0 MB    | : 100% 1.0/1 [00:30<00:00,  2.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# proj-9.5.1           | 3.0 MB    | : 100% 1.0/1 [00:30<00:00,  2.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.7 MB    | : 100% 1.0/1 [00:31<00:00,  2.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
# eccodes-2.41.0       | 4.3 MB    | : 100% 1.0/1 [00:36<00:00,  3.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %%
import metview as mv
from ecmwf.opendata import Client

# %% [markdown]
# Great — let’s go step-by-step in English as you asked. Here’s what those two lines do and how they fit together.
#
# **`import metview as mv`**
#
# * Imports the **Metview** Python API and gives it the short name `mv`.
# * Metview is a toolkit (with a C++ core and Python bindings) made by ECMWF to **read, process and visualise meteorological fields** (GRIB, NetCDF, etc.).
# * Typical capabilities you’ll use:
#
#   * read data: `mv.read("file.grib")`
#   * create plotting descriptors (not the plot itself): `mv.mcont(...)`, `mv.mwind(...)`, `mv.geoview(...)`, `mv.mtext(...)`
#   * configure output: `mv.setoutput('jupyter', width=..., height=...)`
#   * render the plot: `mv.plot(view, field, style, ...)` — this is when descriptor objects are evaluated and the image is produced.
# * Important behavior: many `mv.*` calls return **descriptor objects** (settings). Nothing is drawn until you call `mv.plot()` (or explicitly read/execute a field).
#
# **`from ecmwf.opendata import Client`**
#
# * Imports the `Client` class from the `ecmwf-opendata` package.
# * Purpose: programmatic access to ECMWF’s **OpenData** content — it constructs the correct URLs and downloads forecast/analysis GRIBs or other files from ECMWF servers.
# * Main usage pattern:
#
#   * create a client: `client = Client()`
#   * request a file: `client.retrieve(date=..., time=..., step=..., stream=..., param=..., target="out.grib")`
#   * the method builds the HTTP request, downloads the file and writes it to `target`.
# * Failure modes you’ve already seen: if the requested file doesn’t exist on the server the client will raise an HTTP error (404). Also pay attention to parameter types (e.g. `time` is typically an integer hour like `0`, `6`, `12`, `18`).
#
# **How they work together (typical workflow)**
#
# 1. Use `Client` to download a GRIB file to disk.
# 2. Use Metview to read that file and create plot descriptors.
# 3. Call `mv.plot(...)` to render the map (in a Jupyter cell or a file).

# %%
client = Client("ecmwf", beta=False)

# %% [markdown]
# That line is creating an **ECMWF OpenData client object** with two specific settings:
#
#
# ### 1️`"ecmwf"`
#
# * This is the **data source identifier**.
# * The `Client` class in `ecmwf-opendata` can point to different back-ends (for example: `"ecmwf"` for ECMWF’s own operational forecast service, `"azure"` for the Microsoft-hosted copy, `"aws"` for the Amazon-hosted copy, `"cds"` for Copernicus, etc.).
# * By passing `"ecmwf"`, you’re telling it:
#
#   > “Use ECMWF’s **own servers** ([https://data.ecmwf.int](https://data.ecmwf.int)) to get the files.”
#
#
#
# ### 2️`beta=False`
#
# * ECMWF sometimes runs a **beta** version of their OpenData service with early access to products, new formats, or experimental changes.
# * If you set `beta=True`, the client would point to the beta endpoints (often a different directory structure or file naming).
# * With `beta=False`, you’re explicitly saying:
#
#   > “Use the **production** service, not the beta/testing one.”
#
#
# ### What happens internally
#
# When you run that line:
#
# 1. The `Client` constructor saves those settings in the object.
# 2. It builds internal URL templates based on the chosen source (`"ecmwf"`) and version (`beta` flag).
# 3. Later, when you call `client.retrieve(...)`, it fills those templates with your `date`, `time`, `step`, etc., to generate the correct URL for the file you want.

# %% [markdown]
# ## Retrieve requests
# This product uses parameters at different vertical levels.
# Mean sea level pressure belongs to the surface parameters, while u and v at 200 hPa are pressure level parameters.
# The two types of levels can not be in the same request, so we need to make two requests for them.
#
# * These are **lists of parameter short names** from the ECMWF parameter table.
# * `sfc_parameters` → for **surface fields** (`sfc` = surface), here only `"msl"` = mean sea level pressure.
# * `pl_parameters` → for **pressure level fields** (`pl` = pressure levels), here `"u"` and `"v"` = the eastward and northward wind components.
# * When you later pass `param=sfc_parameters` or `param=pl_parameters` into `client.retrieve(...)`, the client will request *all* those parameters in a single GRIB file.
# * These are just **strings holding file names** for the downloaded GRIB files.
# * `sfc_filename` → where the surface parameters will be saved.
# * `pl_filename` → where the pressure level parameters will be saved.
# * This separation means you can download and store them independently (surface vs. upper air) without overwriting one file.
#
# ### **Why do it this way?**
#
# 1. **Clarity** – You can see at a glance which parameters you’re requesting for each type of level.
# 2. **Reusability** – You can pass these lists and filenames into `client.retrieve()` multiple times without retyping them.
#
#    ```python
#    client.retrieve(date=..., levtype='sfc', param=sfc_parameters, target=sfc_filename)
#    client.retrieve(date=..., levtype='pl', levelist=200, param=pl_parameters, target=pl_filename)
#    ```
# 3. **Efficiency** – ECMWF lets you request multiple parameters in the same file if they share the same metadata (date, time, step, level type, etc.), so grouping them like this saves you separate downloads.

# %%
sfc_parameters = ['msl']
pl_parameters = ['u', 'v']
sfc_filename = 'medium-mslp-wind200-sfc.grib'
pl_filename = 'medium-mslp-wind200-pl.grib'

# %% [markdown]
# Next code is telling the ECMWF OpenData client:
#
# ---
#
# ### **What it’s requesting**
#
# * **`date=0`**
#   In the `ecmwf-opendata` package, passing `0` as the date is a shortcut meaning
#
#   > “Use **today’s date** in UTC.”
#   > It will internally replace it with the current date in `YYYY-MM-DD` format.
#
# * **`time=0`**
#   Here `0` means
#
#   > “Use the **00 UTC run** of the forecast.”
#   > This must be an integer hour: 0, 6, 12, or 18 for ECMWF operational forecasts.
#
# * **`step=12`**
#   Forecast lead time (in hours) from the model start time.
#   Here: 12 hours after the run start.
#
# * **`stream="oper"`**
#   Tells ECMWF you want the operational (high-resolution) forecast, not an ensemble or other stream.
#
# * **`type="fc"`**
#   Means **forecast** data (as opposed to `"an"` = analysis).
#
# * **`levtype="sfc"`**
#   Means surface level data (not pressure levels).
#
# * **`param=sfc_parameters`**
#   The list we defined earlier, here `['msl']` = mean sea level pressure.
#
# * **`target=sfc_filename`**
#   Where to save the GRIB file — here `'medium-mslp-wind200-sfc.grib'`.
#
#
# >### **Why `0` and `0`?**
# >
# >* It’s a convenience feature — you don’t need to manually type `"2025-08-12"` or guess the latest date.
# * You only use this safely if you know **today’s 00 UTC run** is already published and complete.
#   If you run this too soon after model start, ECMWF may not have all `step=12` files ready yet, and you’ll get the 404 error you saw before.
#
#
#
# Example with explicit date/time (same as above but without shortcuts):
#
# ```python
# client.retrieve(
#     date="2025-08-12",
#     time=0,
#     step=12,
#     stream="oper",
#     type="fc",
#     levtype="sfc",
#     param=['msl'],
#     target='medium-mslp-wind200-sfc.grib'
# )
# ```
#
# ---
#
# If you want, I can show you how to make `date` and `time` **auto-select the most recent available run** instead of hard-coding `0,0` or a fixed date, so you never hit missing data errors. That’s what meteorological scripts normally do for operational workflows.
#
#
#
# Setting date to 0 will download today's data.
# Removing date and time altogether from the request will download the latest data.
# Try commenting out date and time to download latest forecast!

# %%
client.retrieve(
    date=0,
    time=0,
    step=12,
    stream="oper",
    type="fc",
    levtype="sfc",
    param=sfc_parameters,
    target=sfc_filename
)
# Out:
# 20250812000000-12h-oper-fc.grib2:   0%|          | 0.00/622k [00:00<?, ?B/s]

# %%
client.retrieve(
    date=0,
    time=0,
    step=12,
    stream="oper",
    type="fc",
    levtype="pl",
    levelist=200,
    param=pl_parameters,
    target=pl_filename
)
# Out:
# Recovering from HTTP error [429 Too Many Requests], attempt 1 of 500
# Retrying in 120 seconds
# 20250812000000-12h-oper-fc.grib2:   0%|          | 0.00/1.34M [00:00<?, ?B/s]

# %% [markdown]
# ### How it works
#
# * **`for hours_back in range(0, 48, 6)`** → tries 0h ago, 6h ago, 12h ago, … up to 48h ago.
# * **`hour = dt.hour - (dt.hour % 6)`** → ECMWF runs only start at 0, 6, 12, 18 UTC; this rounds down to the nearest one.
# * In each loop, it:
#
#   1. Downloads the surface GRIB.
#   2. Downloads the pressure-level GRIB.
#   3. If both succeed, it stops and returns the date/hour.
# * If either fails, it moves to the next earlier run.
#
# ---
#
# If you want, I can add a **`print()` status line for each attempt**, so you can see exactly which runs are being tested until one works. That way you’ll know how far back it had to go.
#
# Do you want me to add that logging?

# %% [markdown]
# ## Reading and processing the data
# Now we can use **Metview's read() function** to read the files.

# %%
from datetime import datetime, timedelta
from ecmwf.opendata import Client

def latest_run():
    # Loop backwards in 6-hour steps, max 48h back
    for hours_back in range(0, 48, 6):
        dt = datetime.utcnow() - timedelta(hours=hours_back)
        date_str = dt.strftime("%Y-%m-%d")
        hour = dt.hour - (dt.hour % 6)  # round down to nearest 6h

        try:
            # --- Surface fields ---
            client.retrieve(
                date=date_str,
                time=hour,
                step=12,
                stream="oper",
                type="fc",
                levtype="sfc",
                param=sfc_parameters,
                target=sfc_filename
            )

            # --- Pressure level fields ---
            client.retrieve(
                date=date_str,
                time=hour,
                step=12,
                stream="oper",
                type="fc",
                levtype="pl",
                levelist=200,
                param=pl_parameters,
                target=pl_filename
            )

            print(f"✅ Data found for {date_str} {hour:02d} UTC")
            return date_str, hour  # stop after both succeed

        except Exception as e:
            # If *either* retrieval fails, try the previous run
            continue

    # If we finish the loop without finding any
    raise RuntimeError("❌ No valid run found in the last 48 hours.")

# Create the ECMWF client
client = Client(source="ecmwf")

# Call the function
date_found, hour_found = latest_run()
# Out:
# 20250812000000-12h-oper-fc.grib2:   0%|          | 0.00/622k [00:00<?, ?B/s]
# 20250812000000-12h-oper-fc.grib2:   0%|          | 0.00/1.34M [00:00<?, ?B/s]
# ✅ Data found for 2025-08-12 00 UTC

# %% [markdown]
# Those two lines are **Metview** reading the GRIB files you just downloaded with `client.retrieve()`.
#
#
# * `mv.read()` is Metview’s function for **loading meteorological data files** (GRIB, NetCDF, BUFR, etc.) into a Python object that Metview can work with.
# * Here `pl_filename` is `'medium-mslp-wind200-pl.grib'` (from your earlier variable definition).
# * This GRIB contains:
#   * Variables `"u"` and `"v"` at 200 hPa (from `pl_parameters = ['u', 'v']`).
#   * They represent the **eastward (u)** and **northward (v)** wind components.
# * The result, `wind200`, is a **Metview Fieldset** object — essentially a list of GRIB fields you can filter, style, and plot.
# * `sfc_filename` is `'medium-mslp-wind200-sfc.grib'`.
#   * This file contains `"msl"` = mean sea level pressure.
#   * `msl` is also a Fieldset object.
#
#
#
# * `client.retrieve()` just downloads files to disk — it doesn’t load them into memory.
# * Metview needs the data in a Fieldset object to work with plotting commands like `mv.plot()`, `mv.mcont()`, `mv.mwind()`, etc.
# * After `mv.read()`, you can:
#
#   * Plot them directly:
#
#     ```python
#     mv.plot(msl)
#     ```
#   * Combine them with styles:
#
#     ```python
#     mv.plot(view, msl, mslp_contour, wind200, wind_arrows)
#     ```
#   * Filter or subset:
#
#     ```python
#     mv.read(sfc_filename, parameter='msl')
#     ```
#
# ---
#
# In other words — those two lines are the bridge between **files on disk** and **Metview’s in-memory plotting objects**.
#
# If you want, next I can explain **how Metview knows which fields are which inside `wind200`** and how to extract, for example, just the `"u"` or just the `"v"` field for plotting. Would you like me to?

# %%
wind200 = mv.read(pl_filename)
msl = mv.read(sfc_filename)

# %%
 mv.plot(msl)
# Out:
# Image(value=b'', layout="Layout(visibility='hidden')")
# Label(value='Generating plots....')

# %%
import metview as mv

# define coastlines
coast = mv.mcoast(
    map_coastline_colour="charcoal",
    map_coastline_resolution="medium",
    map_coastline_land_shade="on",
    map_coastline_land_shade_colour="cream",
    map_coastline_sea_shade="off",
    map_boundaries="on",
    map_boundaries_colour= "charcoal",
    map_boundaries_thickness = 1,
    map_disputed_boundaries = "off",
    map_grid_colour="tan",
    map_label_height=0.35,
)

# Definir la vista de Europa y el estilo de las isobaras
view_europe = mv.geoview(
    map_area_definition="corners",
    area=[30, -20, 70, 40],  # Europa: [lat_min, lon_min, lat_max, lon_max]
    coastlines=coast,
)


# mostrar gráfico
mv.setoutput('jupyter', plot_widget=False)
mv.plot(view_europe, msl)

# %% [markdown]
# The **describe()** function will give us the overview of the dataset.

# %%
wind200.describe()
# Out:
#
#                 <table>
#                 <tr><th>parameter</th><th>typeOfLevel</th><th>level</th><th>date</th><th>time</th><th>step</th><th>number</th><th>paramId</th><th>class</th><th>stream</th><th>type</th><th>experimentVersionNumber</th></tr>
#                 <tr><th style='text-align: right;'>u</th><td style='text-align: left;'>isobaricInhPa</td><td style='text-align: left;'>200</td><td style='text-align: left;'>20250812</td><td style='text-align: left;'>0</td><td style='text-align: left;'>12</td><td style='text-align: left;'>None</td><td style='text-align: left;'>131</td><td style='text-align: left;'>od</td><td style='text-align: left;'>oper</td><td style='text-align: left;'>fc</td><td style='text-align: left;'>0001</td></tr><tr><th style='text-align: right;'>v</th><td style='text-align: left;'>isobaricInhPa</td><td style='text-align: left;'>200</td><td style='text-align: left;'>20250812</td><td style='text-align: left;'>0</td><td style='text-align: left;'>12</td><td style='text-align: left;'>None</td><td style='text-align: left;'>132</td><td style='text-align: left;'>od</td><td style='text-align: left;'>oper</td><td style='text-align: left;'>fc</td><td style='text-align: left;'>0001</td></tr>
#                 </table>

# %% [markdown]
# And an overview of one parameter, where we can see more information, such as units or type of level.

# %%
msl.describe('msl')
# Out:
#
#                 <table>
#                 <tr></tr>
#                 <tr><th style='text-align: right;'>shortName</th><td style='text-align: left;'>msl</td></tr><tr><th style='text-align: right;'>name</th><td style='text-align: left;'>Mean sea level pressure</td></tr><tr><th style='text-align: right;'>paramId</th><td style='text-align: left;'>151</td></tr><tr><th style='text-align: right;'>units</th><td style='text-align: left;'>Pa</td></tr><tr><th style='text-align: right;'>typeOfLevel</th><td style='text-align: left;'>meanSea</td></tr><tr><th style='text-align: right;'>level</th><td style='text-align: left;'>0</td></tr><tr><th style='text-align: right;'>date</th><td style='text-align: left;'>20250812</td></tr><tr><th style='text-align: right;'>time</th><td style='text-align: left;'>0</td></tr><tr><th style='text-align: right;'>step</th><td style='text-align: left;'>12</td></tr><tr><th style='text-align: right;'>number</th><td style='text-align: left;'>None</td></tr><tr><th style='text-align: right;'>class</th><td style='text-align: left;'>od</td></tr><tr><th style='text-align: right;'>stream</th><td style='text-align: left;'>oper</td></tr><tr><th style='text-align: right;'>type</th><td style='text-align: left;'>fc</td></tr><tr><th style='text-align: right;'>experimentVersionNumber</th><td style='text-align: left;'>0001</td></tr>
#                 </table>

# %% [markdown]
# We can use **ls()** function to list all the fields in the file we downloaded.

# %%
wind200.ls()
# Out:
#         centre shortName  typeOfLevel    level  dataDate  dataTime stepRange  \
# Message
# 0        ecmf       v     isobaricInhPa   200   20250812      0        12
# 1        ecmf       u     isobaricInhPa   200   20250812      0        12
#
#         dataType number   gridType
# Message
# 0          fc     None   regular_ll
# 1          fc     None   regular_ll

# %% [markdown]
# In order to calculate the speed, we need to filter out u and v component and use the **speed()** function for the calculation.

# %%
u = wind200.select(shortName ='u')
v = wind200.select(shortName ='v')
speed = mv.speed(u,v)
speed.describe()
# Out:
#
#                 <table>
#                 <tr><th>parameter</th><th>typeOfLevel</th><th>level</th><th>date</th><th>time</th><th>step</th><th>number</th><th>paramId</th><th>class</th><th>stream</th><th>type</th><th>experimentVersionNumber</th></tr>
#                 <tr><th style='text-align: right;'>ws</th><td style='text-align: left;'>isobaricInhPa</td><td style='text-align: left;'>200</td><td style='text-align: left;'>20250812</td><td style='text-align: left;'>0</td><td style='text-align: left;'>12</td><td style='text-align: left;'>None</td><td style='text-align: left;'>10</td><td style='text-align: left;'>od</td><td style='text-align: left;'>oper</td><td style='text-align: left;'>fc</td><td style='text-align: left;'>0001</td></tr>
#                 </table>

# %% [markdown]
# Mean sea level pressure data has unites Pa, but we want to plot it in hPa, therefore we need to convert it.

# %%
msl /= 100

# %% [markdown]
# And finally, we can plot the data on the map.

# %%
# define coastlines
coast = mv.mcoast(
    map_coastline_colour="charcoal",
    map_coastline_resolution="medium",
    map_coastline_land_shade="on",
    map_coastline_land_shade_colour="cream",
    map_coastline_sea_shade="off",
    map_boundaries="on",
    map_boundaries_colour= "charcoal",
    map_boundaries_thickness = 1,
    map_disputed_boundaries = "off",
    map_grid_colour="tan",
    map_label_height=0.35,
)

# define view
# Definir la vista de Europa y el estilo de las isobaras
view = mv.geoview(
    map_area_definition="corners",
    area=[30, -20, 70, 40],  # Europa: [lat_min, lon_min, lat_max, lon_max]
    coastlines=coast,
)

#define styles
speed_shade = mv.mcont(legend= "on",
                contour_automatics_settings = "style_name",
                contour_style_name = "sh_grn_f30t100i10")

mslp_contour = mv.mcont(legend= "on",
                contour_automatics_settings = "style_name",
                contour_style_name = "ct_blk_i5_t2")

wind_arrows = mv.mwind(
    wind_thinning_factor=5, wind_arrow_colour="mustard"
)

title = mv.mtext(
    text_lines=["Mean sea level pressure and wind at 200 hPa",
                "START TIME: <grib_info key='base-date' format='%a %d %B %Y %H' where='shortName=msl' /> ",
                "VALID TIME: <grib_info key='valid-date' format='%a %d %B %Y %H' where='shortName=msl' />, STEP: <grib_info key='step' where='shortName=msl' />"],
    text_font_size=0.4,
    text_colour         = 'charcoal')

ecmwf_text = mv.mtext(
    text_lines          = ["© European Centre for Medium-Range Weather Forecasts (ECMWF)",
                           "Source: www.ecmwf.int Licence: CC-BY-4.0 and ECMWF Terms of Use",
                            "https://apps.ecmwf.int/datasets/licences/general/"],
    text_justification  = 'center',
    text_font_size      = 0.3,
    text_mode           = "positional",
    text_box_x_position = 6.,
    text_box_y_position = -0.2,
    text_box_x_length   = 8,
    text_box_y_length   = 2,
    text_colour         = 'charcoal')

# generate plot
mv.setoutput('jupyter', plot_widget=False)
mv.plot(view, speed, speed_shade, wind200, wind_arrows, msl, mslp_contour, title, ecmwf_text)

# %% [markdown]
# To generate the png file you can run the following cell.

# %%
png = mv.png_output(
      output_name = "medium-mslp-wind200",   # specify relative or full path
      output_title = "medium-mslp-wind200",    # title used by a viewer
      output_width = 1000,                 # set width in pixels
)
mv.setoutput(png)
mv.plot(view, speed, speed_shade, wind200, wind_arrows, msl, mslp_contour, title, ecmwf_text)

# %% [markdown]
# Note that plot produced using open data dataset will slightly differ from one from Open Charts. This is due to different resolution of the data.
# Open data is on 0.25x0.25 resolution, while high resolution data is 0.1x0.1 grid.
