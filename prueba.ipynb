# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanZapa7a/AINavalEngineering/blob/main/prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### [Using Kaggle Datasets in Google Colab](https://stackoverflow.com/questions/49310470/using-kaggle-datasets-in-google-colab):
#
# **A**. `An API key is needed for` [Kaggle](https://www.kaggle.com/settings)
#
# To create an API key in Kaggle, you should normally follow these general steps:
#
# 1. **`Go to the Kaggle website`:**
#    Open your web browser and go to [`Kaggle`](https://www.kaggle.com/).
#
# 2. **`Sign in`:**
#    Sign in to your Kaggle account. *``If you do not have an account, you will need to register``*.
#
# 3. **`User configuration`:**
#    Once logged in, go to your account settings. This is usually accessed by _``clicking on your profile picture in the top right corner of the Kaggle site and selecting "Settings"``_.
#
# 4. **`API key`:**
#    _``In your account settings``_, there should be a _``section for APIs``_. You may find a button for _``"Create new token"``_ or something similar. _``Click on it``_.
#
# 5. **`Download API key`:**
#    After creating the API key, you will usually _``be asked to download a JSON file containing your key``_. Store this file securely, as it contains sensitive information.
#
# 6. **`Using`:**
#    You can _``use this API key for various Kaggle API operations``_, such as downloading datasets, entering competitions, etc.
#
# > **Note**: Please, this specific steps may vary slightly depending on any changes Kaggle has made to its platform since this release. Always consult the [_``latest Kaggle documentation``_](https://www.kaggle.com/docs/api) or help resources for the most accurate and up-to-date information.
#
# **B**. `Navigate to `[`Colab`](https://colab.research.google.com/). _``Open your ipynb file``_ that we will use with Kaggle to download a dataset.
#
# **C**. ``Upload your kaggle.json file``: Use the *``following snipet``* in a code cell, which will allow you to browse your disk for the `kaggle.json` file downloaded from Kaggle.
#
# To allow file uploads in an environment other than Google Colab, you can use an alternative approach based on the environment you're in. Here's a way to modify the code to handle file uploads both in Google Colab and in other environments using a command-line interface:
#
# 1. **Google Colab**:
#     - Imports and mounts Google Drive.
#     - Uses `files.upload()` to allow file uploads through the Colab interface.
#
# ```python
# # Import necessary libraries
# from google.colab import drive
# from google.colab import files
#
# # Mount Google Drive
# drive.mount('/content/drive')
#
# # Use files.upload() to upload files through the Colab interface
# uploaded_files = files.upload()
# ```
#
# 2. **Other Environments no GoogleColab**:
#     - Defines an `upload_file()` function that prompts the user to enter the full path of the file they want to upload.
#     - Checks if the file exists at the provided path.
#     - If the file is found, it prints a message confirming the upload.
#     - If the file is not found, it prompts the user to check the path and try again.
#
# ```python
# import os
#
# def upload_file():
#     # Prompt the user to enter the full path of the file they want to upload
#     file_path = input("Please enter the full path of the file you want to upload: ")
#
#     # Check if the file exists at the provided path
#     if os.path.exists(file_path):
#         print(f"File '{file_path}' uploaded successfully!")
#         # You can add additional code here to handle the uploaded file
#         return file_path
#     else:
#         print("File not found. Please check the path and try again.")
#         return None
#
# # Call the function to test the file upload process
# uploaded_file_path = upload_file()
# ```

# %%
try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    from google.colab import drive, files
    drive.mount('/content/drive')
    print("Google Drive is mounted.")
    uploaded = files.upload()
    for filename in uploaded.keys():
        print(f'You uploaded file: "{filename}"')
else:
    import os

    def upload_file():
        file_path = input("Please enter the full path to the file you want to upload: ")
        if os.path.isfile(file_path):
            print(f'You uploaded file: "{file_path}"')
            return file_path
        else:
            print("File not found. Please check the path and try again.")
        return None

    uploaded_file = upload_file()
    if uploaded_file:
        # Here you can add code to handle the uploaded file
        pass
    else:
        print("No file uploaded.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Google Drive is mounted.
#      <input type="file" id="files-288ea355-e429-48f5-b6e0-078e2d6af388" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-288ea355-e429-48f5-b6e0-078e2d6af388">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
# %pip install -q kaggle

# %%
# %mkdir -p ~/.kaggle
# %cp ./kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# %ls -al ~
# Out:
# total 72
# drwx------ 1 root root 4096 Feb 27 17:00 ./
# drwxr-xr-x 1 root root 4096 Feb 27 16:58 ../
# -r-xr-xr-x 1 root root 1220 Jan  1  2000 .bashrc*
# drwxr-xr-x 1 root root 4096 Feb 25 14:32 .cache/
# drwxr-xr-x 1 root root 4096 Feb 27 17:02 .config/
# drwxr-xr-x 5 root root 4096 Feb 25 14:32 .ipython/
# drwx------ 1 root root 4096 Feb 25 14:32 .jupyter/
# drwxr-xr-x 2 root root 4096 Feb 27 17:17 .kaggle/
# drwxr-xr-x 2 root root 4096 Feb 27 16:59 .keras/
# drwx------ 3 root root 4096 Feb 25 14:14 .launchpadlib/
# drwxr-xr-x 1 root root 4096 Feb 25 14:32 .local/
# drwxr-xr-x 4 root root 4096 Feb 25 14:32 .npm/
# -rw-r--r-- 1 root root  161 Jul  9  2019 .profile
# -r-xr-xr-x 1 root root  254 Jan  1  2000 .tmux.conf*
# -rw-r--r-- 1 root root  211 Feb 25 14:32 .wget-hsts

# %%
# !kaggle datasets list
# Out:
# ref                                                                   title                                              size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# asinow/car-price-dataset                                              Car Price Dataset                                 135KB  2025-01-26 19:53:28          18961        306  1.0
# asinow/diabetes-dataset                                               Diabetes Dataset                                  224KB  2025-02-20 08:38:56           1274         28  1.0
# mahmoudelhemaly/students-grading-dataset                              Student Performance & Behavior Dataset            508KB  2025-02-17 17:38:46           2644         45  1.0
# ...

# %%
# !kaggle datasets list -s "cwiloc"
# Out:
# ref                                   title                                 size  lastUpdated          downloadCount  voteCount  usabilityRating
# ------------------------------------  -----------------------------------  -----  -------------------  -------------  ---------  ---------------
# cwiloc/climate-data-from-ocean-ships  Ocean Ship Logbooks (1750-1850)       19MB  2017-11-16 00:59:48           4492        115  0.64705884
# jessevent/all-kaggle-datasets         Complete Kaggle Datasets Collection  390KB  2018-01-16 12:32:58           3152        146  0.8235294

# %%
# !kaggle datasets download -d cwiloc/climate-data-from-ocean-ships --unzip --force
# Out:
# Dataset URL: https://www.kaggle.com/datasets/cwiloc/climate-data-from-ocean-ships
# License(s): CC0-1.0
# ...
#  92% 17.0M/18.5M [00:00<00:00, 21.0MB/s]
# 100% 18.5M/18.5M [00:00<00:00, 23.4MB/s]

# %%
# !ls -al *.csv
# Out:
# -rw-r--r-- 1 root root 213308061 Feb 27 17:22 CLIWOC15.csv
# -rw-r--r-- 1 root root    157565 Feb 27 17:22 Geodata.csv
# -rw-r--r-- 1 root root      3207 Feb 27 17:22 Lookup_ES_WindDirection.csv
# -rw-r--r-- 1 root root     43008 Feb 27 17:22 Lookup_ES_WindForce.csv
# -rw-r--r-- 1 root root      1764 Feb 27 17:22 Lookup_FR_WindDirection.csv
# -rw-r--r-- 1 root root      9534 Feb 27 17:22 Lookup_FR_WindForce.csv
# -rw-r--r-- 1 root root      3573 Feb 27 17:22 Lookup_NL_WindDirection.csv
# -rw-r--r-- 1 root root     75417 Feb 27 17:22 Lookup_NL_WindForce.csv
# -rw-r--r-- 1 root root      1707 Feb 27 17:22 Lookup_UK_WindDirection.csv
# -rw-r--r-- 1 root root     45725 Feb 27 17:22 Lookup_UK_WindForce.csv
# -rw-r--r-- 1 root root   6053201 Feb 27 17:22 Magnetic_Declinations.csv
# -rw-r--r-- 1 root root     67945 Feb 27 17:22 ShipLogbookID.csv
# -rw-r--r-- 1 root root      4281 Feb 27 17:22 Weather.csv

# %% [markdown]
# ## About Dataset
#
# In the mid-eighteenth to nineteenth centuries, navigating the open ocean was an imprecise and often dangerous feat. In order to calculate their daily progress and avoid running/sailing into the unknown, a ship's crew kept a detailed logbook with data on winds, waves, and any remarkable weather.
#
# Handwritten in archived logbooks, these rich datasets were nearly impossible to study until the European Union funded their digitization in 2001. You can visit the EU project [website](https://pendientedemigracion.ucm.es/info/cliwoc/) for detailed information on the countries and ships included.
#
# We're hosting the full 1750-1850 dataset on Kaggle to promote the exploration of this unique and invaluable climatology resource.
#
#
# The database consists of 287,114 logbooks written aboard Dutch, English, French, and Spanish sailing ships. The vast majority of these logbooks date from between 1750 and 1850, yet four ship logbooks were incorporated that predate 1750. These were centuries of European imperial expansion, and so the logbooks record the activities of sailors - both civilian and military - in oceans that span the entire globe.
#
# European sailors started writing daily logs in the sixteenth century, as they began to regularly leave familiar shores. One reason was that the leaders of increasingly bureaucratized admiralties and merchant companies wished to evaluate the performance of their officers.
#
# A more important reason had to do with the limits of contemporary navigation. From the mid-seventeenth century, sailors could determine latitude with reasonable accuracy even while far from coastal landmarks. Yet until the eighteenth-century invention, and the widespread nineteenth-century implementation, of the marine chronometer, they could only estimate longitude using “dead reckoning.”
#
# Dead reckoning was a technique that required knowledge of three essential variables: a ship’s speed, measured by log line; its course, determined by compass; and any drift by the ship from its course. That last variable responded primarily to the direction and velocity of the wind.
#
# To have even a rough sense of where they were, sailors needed to obsessively keep track of the wind. Most ship logbooks therefore abound with reliable, detailed, and almost unbroken weather observations that sailors wrote down whenever the wind changed. That makes them priceless sources for graphing and mapping past climate changes, particularly as they unfolded at sea - where researchers often have fragmentary or low resolution evidence. Moreover, they are unique - and uniquely underused - sources for connecting weather events and climate trends to human history.
#
# In the CLIWOC project, researchers quantified all of this information and entered it into what was originally a Microsoft Access database. They made the information available online for free, yet over time its formatting became increasingly obsolete. To use the database, researchers had to download and often pay for an outdated program that few knew how to use.

# %%
import pandas as pd
df = pd.read_csv('CLIWOC15.csv')
df.head(20)
# Out:
# <ipython-input-28-dd71f7c52a6c>:2: DtypeWarning: Columns (5,6,7,8,11,13,18,19,23,24,25,26,28,29,30,34,35,38,43,44,46,73,77,81,82,84,85,87,88,94,96,97,98,99,111,114,116,119,120,122,124,125,127,129,131,133,135,137,140) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('CLIWOC15.csv')
#     RecID InstAbbr                    InstName InstPlace InstLand NumberEntry  \
# 0     108      MNM  Archivo Museo Naval Madrid    Madrid    Spain         NaN
# 1     109      MNM  Archivo Museo Naval Madrid    Madrid    Spain         NaN
# 2     110      MNM  Archivo Museo Naval Madrid    Madrid    Spain         NaN
# 3     111      MNM  Archivo Museo Naval Madrid    Madrid    Spain         NaN
# 4     112      MNM  Archivo Museo Naval Madrid    Madrid    Spain         NaN
# 5     113      MNM  Archivo Museo Naval Madrid    Madrid    Spain         NaN
# 6     114      MNM  Archivo Museo Naval Madrid    Madrid    Spain         NaN
# ...

# %%
df = pd.read_csv('Geodata.csv')
df.head()
# Out:
#    ID             Place  DecLatitude  DecLongitude  \
# 0   1               NaN     0.000000      0.000000
# 1   2  2e hoek van Java    -6.630000    105.370000
# 2   3  3e hoek van Java    -6.470000    105.670000
# 3   4  4e hoek van Java    -6.070000    105.870000
# 4   5          Abrolhos   -17.966667    -38.683333
#
#                               Source                ModernName  \
# 0                                NaN                       NaN
# 1  Atlas van Tropisch Nederland 1938                       NaN
# 2  Atlas van Tropisch Nederland 1938                       NaN
# 3  Atlas van Tropisch Nederland 1938                       NaN
# 4           Times Atlas of the World  Arquipelago dos Abrolhos
#
#   Alternative.Name                    Near           Ocean Spanish Dutch  \
# 0              NaN                     NaN             NaN     NaN   NaN
# 1              NaN                     NaN             NaN     NaN   NaN
# ...

# %%
# @title Spanish

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('Spanish').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# !pip install cartopy
import cartopy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 82.3 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import pandas as pd

# Cargar datos (Ejemplo: archivo CSV con columnas "latitude" y "longitude")
df = pd.read_csv("Geodata.csv")

# Crear la figura con la proyección adecuada
fig = plt.figure(figsize=(12, 6))
ax = plt.axes(projection=ccrs.Robinson())  # Proyección global bonita
ax.set_global()

# Agregar océanos y líneas de costa
ax.add_feature(cfeature.OCEAN, color='lightblue')
ax.add_feature(cfeature.COASTLINE, linewidth=0.5)

# Graficar rutas marítimas
plt.scatter(df["DecLongitude"], df["DecLatitude"], s=0.1, color='red', alpha=0.5, transform=ccrs.PlateCarree())

# Mostrar el mapa
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/110m_physical/ne_110m_ocean.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# /usr/local/lib/python3.11/dist-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/110m_physical/ne_110m_coastline.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# Cargar el CSV
df = pd.read_csv("Geodata.csv")

# Filtrar valores nulos en coordenadas
df = df.dropna(subset=["DecLatitude", "DecLongitude"])

# Crear el mapa
fig = plt.figure(figsize=(12, 6))
ax = plt.axes(projection=ccrs.Robinson())  # Proyección global
ax.set_global()

# Agregar océanos y líneas de costa
ax.add_feature(cfeature.OCEAN, color="lightblue")
ax.add_feature(cfeature.COASTLINE, linewidth=0.5)

# Graficar los puntos
plt.scatter(
    df["DecLongitude"], df["DecLatitude"],
    s=1, color="red", alpha=0.5, transform=ccrs.PlateCarree()
)

# Mostrar el mapa
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# Cargar el CSV
df = pd.read_csv("Geodata.csv")

# Filtrar valores nulos en coordenadas
df = df.dropna(subset=["DecLatitude", "DecLongitude"])

# Crear la figura con proyección
fig = plt.figure(figsize=(12, 6))
ax = plt.axes(projection=ccrs.Robinson())  # Proyección global
ax.set_global()

# Agregar océanos y líneas de costa
ax.add_feature(cfeature.OCEAN, color="lightblue")
ax.add_feature(cfeature.COASTLINE, linewidth=0.5)

# Dibujar las rutas conectando los puntos
ax.plot(
    df["DecLongitude"], df["DecLatitude"],
    linestyle="-", linewidth=0.5, color="red",
    alpha=0.7, transform=ccrs.PlateCarree()
)

# Mostrar el mapa
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# Cargar el CSV
df = pd.read_csv("CLIWOC15.csv")

# Filtrar valores nulos en coordenadas
df = df.dropna(subset=["Lon3", "Lat3"])

# Crear figura con proyección
fig = plt.figure(figsize=(12, 6))
ax = plt.axes(projection=ccrs.Robinson())
ax.set_global()

# Agregar océanos y líneas de costa
ax.add_feature(cfeature.OCEAN, color="lightblue")
ax.add_feature(cfeature.COASTLINE, linewidth=0.5)

# Verificar si hay una columna ID (o similar)
if "ShipName" in df.columns:
    for ship, group in df.groupby("ShipName"):  # Agrupar por barco
        ax.plot(
            group["Lon3"], group["Lat3"],
            linestyle="-", linewidth=0.5, alpha=0.7, transform=ccrs.PlateCarree()
        )
else:
    print("No se encontró una columna ShipName. Asegúrate de tener una para diferenciar rutas.")

# Mostrar el mapa
plt.show()
# Out:
# <ipython-input-29-a35e5d6d15e1>:7: DtypeWarning: Columns (5,6,7,8,11,13,18,19,23,24,25,26,28,29,30,34,35,38,43,44,46,73,77,81,82,84,85,87,88,94,96,97,98,99,111,114,116,119,120,122,124,125,127,129,131,133,135,137,140) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("CLIWOC15.csv")
