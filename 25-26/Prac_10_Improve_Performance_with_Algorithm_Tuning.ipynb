# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanZapa7a/AINavalEngineering/blob/main/Prac_10_Improve_Performance_with_Algorithm_Tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 10: Algorithm Tuning, Saving & Loading Models

# %% [markdown]
# We have discovered ensemble machine learning algorithms for improving the performance of models on our problems.
#
# - **Bagging Ensembles** including Bagged Decision Trees, Random Forest and Extra Trees.
# - **Boosting Ensembles** including AdaBoost and Stochastic Gradient Boosting.
# - **Voting Ensembles** for averaging the predictions for any arbitrary models.
#
# But there is another technique that we can use to improve the
# performance of algorithms on our dataset called `algorithm tuning`.
#
# **Machine learning models are parameterized so that their behavior _can be tuned_ for a given
# problem**.
#
# Models _can have many parameters_ and finding the best **combination of parameters can
# be treated as a search problem**.
#
# In this chapter **you will discover how to tune the parameters of
# machine learning algorithms** in Python using the scikit-learn.
#
# After completing this lesson we
# will know:
# 1. The importance of algorithm parameter tuning to improve algorithm performance.
# 2. How to use a grid search algorithm tuning strategy.
# 3. How to use a random search algorithm tuning strategy.

# %% [markdown]
# ## Machine Learning Algorithm Parameters
# Algorithm tuning is a final step in the process of applied machine learning before finalizing your
# model.
#
# It is sometimes called **hyperparameter optimization** where the **algorithm parameters
# are referred to as hyperparameters**, whereas the **coefficients found by the machine learning
# algorithm itself are referred to as parameters**.
#
# **Optimization suggests the search-nature of the
# problem**.
#
# Phrased as a search problem, you can use different search **strategies to find a good and
# robust parameter or set of parameters** for an algorithm on a given problem.
#
# Python scikit-learn
# provides two simple methods for algorithm parameter tuning:
# - Grid Search Parameter Tuning.
# - Random Search Parameter Tuning.

# %% [markdown]
# ### Grid Search Parameter Tuning
# Grid search is an approach to parameter tuning that will _**methodically build and evaluate a
# model for each combination of algorithm parameters specified in a grid**_. You can perform a grid search using the [GridSearchCV class](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html) .
#
# The example below evaluates different alpha values for
# the Ridge Regression algorithm on the corrosion detection ships dataset. This is a one-dimensional
# grid search.

# %% [markdown]
# ---
# **Load the file from a url to `content/data_sample`**
#
# ---
#
# First of all we will load the file from a url and then save it in `content/data_sample`.

# %%
# !wget -O /content/sample_data/Corrosion_Detection_Ships.csv https://raw.githubusercontent.com/JuanZapa7a/AINavalEngineering/main/Datasets/Corrosion_Detection_Ships.csv
# Out:
# --2025-03-31 09:29:10--  https://raw.githubusercontent.com/JuanZapa7a/AINavalEngineering/main/Datasets/Corrosion_Detection_Ships.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23278 (23K) [text/plain]
# Saving to: ‘/content/sample_data/Corrosion_Detection_Ships.csv’
#
# /content/sample_dat 100%[===================>]  22.73K  --.-KB/s    in 0.001s
#
# 2025-03-31 09:29:11 (14.8 MB/s) - ‘/content/sample_data/Corrosion_Detection_Ships.csv’ saved [23278/23278]

# %% [markdown]
# ---
# **Grid Search for Algorithm Tuning**
#
# ---

# %%
# Grid Search for Algorithm Tuning
import numpy
from pandas import read_csv
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
filename = '/content/sample_data/Corrosion_Detection_Ships.csv'
names = ['Years_since_last_inspection',
              'Water_salinity',
              'Water_pressure',
              'Coating_thickness',
              'Anti_corrosion_concentration',
              'Hull_material_density',
              'Inspection_history',
              'Ship_age',
              'Hull_Condition']
data = read_csv(filename, names=names)
array = data.values
X = array[:,0:8]
Y = array[:,8]
alphas = numpy.array([1,0.1,0.01,0.001,0.0001,0])
param_grid = dict(alpha=alphas)
model = Ridge()
grid = GridSearchCV(estimator=model, param_grid=param_grid)
grid.fit(X, Y)
print(grid.best_score_)
print(grid.best_estimator_.alpha)
# Out:
# 0.27610844129292433
# 1.0

# %% [markdown]
# Running the example lists out the optimal score achieved and the set of parameters in the
# grid that achieved that score. In this case the alpha value of 1.0.

# %% [markdown]
# ### Random Search Parameter Tuning
#
# Random search is an approach to parameter tuning that will **sample algorithm parameters from
# a random distribution (i.e. uniform) for a fixed number of iterations**.
#
# A model is constructed
# and **evaluated for each combination of parameters chosen**. You can perform a random search
# for algorithm parameters using the [RandomizedSearchCV class](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html) .
#
# The example below evaluates
# different **random alpha values between 0 and 1** for the Ridge Regression algorithm on the
# standard diabetes dataset.
#
# A total of **100 iterations are performed with uniformly random alpha
# values selected in the range between 0 and 1** (the range that `alpha` values can take)

# %% [markdown]
# ---
# **Randomized for Algorithm Tuning**
#
# ---

# %%
# Randomized for Algorithm Tuning
import numpy
from pandas import read_csv
from scipy.stats import uniform
from sklearn.linear_model import Ridge
from sklearn.model_selection import RandomizedSearchCV
filename = '/content/sample_data/Corrosion_Detection_Ships.csv'
names = ['Years_since_last_inspection',
              'Water_salinity',
              'Water_pressure',
              'Coating_thickness',
              'Anti_corrosion_concentration',
              'Hull_material_density',
              'Inspection_history',
              'Ship_age',
              'Hull_Condition']
data = read_csv(filename, names=names)
array = data.values
X = array[:,0:8]
Y = array[:,8]
param_grid = {'alpha': uniform()}
model = Ridge()
rsearch = RandomizedSearchCV(estimator=model, param_distributions=param_grid, n_iter=100,
random_state=7)
rsearch.fit(X, Y)
print(rsearch.best_score_)
print(rsearch.best_estimator_.alpha)
# Out:
# 0.2761075573402853
# 0.9779895119966027

# %% [markdown]
# Running the example produces results much like those in the grid search example above. An
# optimal `alpha` value near 1.0 is discovered.

# %% [markdown]
# ## Finalize Your Model
#
# **Finding an accurate machine learning model is not the end of the project**.
#
# In this chapter you
# will discover how **to save and load your machine learning model in Python using scikit-learn**.
#
# This allows you to save your model to file and load it later **in order to make predictions**. It is importatnt that we know:
# 1. The importance of **serializing models** for reuse.
# 2. How to use pickle to **serialize and deserialize machine learning models**.
# 3. How to use **Joblib to serialize and deserialize machine learning models**.

# %% [markdown]
# ### Finalize Your Model with `pickle`
#
# **`Pickle` is the standard way of serializing objects in Python**.
#
# You can use the pickle1 operation
# **to serialize your machine learning algorithms and save the serialized format to a file**.
#
# Later you
# can **load this file to deserialize your model and use it to make new predictions**.
#
# The example
# below demonstrates _**how you can train a logistic regression model on the Corrosion detection ships dataset, save the model to file and load it to make predictions on the unseen test set**_.

# %% [markdown]
# ---
# **Save Model Using Pickle**
#
# ---

# %%
# Save Model Using Pickle
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from pickle import dump
from pickle import load
filename = '/content/sample_data/Corrosion_Detection_Ships.csv'
names = ['Years_since_last_inspection',
              'Water_salinity',
              'Water_pressure',
              'Coating_thickness',
              'Anti_corrosion_concentration',
              'Hull_material_density',
              'Inspection_history',
              'Ship_age',
              'Hull_Condition']
data = read_csv(filename, names=names)
array = data.values
X = array[:,0:8]
Y = array[:,8]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, random_state=7)
# Fit the model on 33%
model = LogisticRegression(max_iter=500)
model.fit(X_train, Y_train)
# save the model to disk
filename = 'finalized_model.sav'
dump(model, open(filename, 'wb'))
# some time later...
# load the model from disk
loaded_model = load(open(filename, 'rb'))
result = loaded_model.score(X_test, Y_test)
print(result)
# Out:
# 0.7874015748031497

# %% [markdown]
# Running the example saves the model to finalized model.sav in your local working
# directory. Load the saved model and evaluating it provides an estimate of accuracy of the model
# on unseen data.

# %% [markdown]
# ### Finalize Your Model with `Joblib`
#
# The [Joblib library](https://pypi.python.org/pypi/joblib) is **part of the SciPy ecosystem** and provides utilities for pipelining Python
# jobs.
#
# It provides utilities for **saving and loading** Python objects that make use of NumPy data
# structures, efficiently .
#
# This can be useful for some machine learning algorithms that require a
# lot of parameters or store the entire dataset (e.g. k-Nearest Neighbors).
#
# The example below
# _**demonstrates how you can train a logistic regression model on the Corrosion Detection Ships
# dataset, save the model to file using Joblib and load it to make predictions on the unseen test
# set**_.

# %% [markdown]
# ---
# **Save Model Using joblib**
#
# ---

# %%
# Save Model Using joblib
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from joblib import dump
from joblib import load
filename = '/content/sample_data/Corrosion_Detection_Ships.csv'
names = ['Years_since_last_inspection',
              'Water_salinity',
              'Water_pressure',
              'Coating_thickness',
              'Anti_corrosion_concentration',
              'Hull_material_density',
              'Inspection_history',
              'Ship_age',
              'Hull_Condition']
data = read_csv(filename, names=names)
array = data.values
X = array[:,0:8]
Y = array[:,8]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, random_state=7)
# Fit the model on 33%
model = LogisticRegression(max_iter=500)
model.fit(X_train, Y_train)
# save the model to disk
filename = 'finalized_model.sav'
dump(model, filename)

# some time later...

# load the model from disk
loaded_model = load(filename)
result = loaded_model.score(X_test, Y_test)
print(result)
# Out:
# 0.7874015748031497

# %% [markdown]
# Running the example saves the model to file as `finalized model.sav` and also creates one
# file for each NumPy array in the model (four additional files). After the model is loaded an
# estimate of the accuracy of the model on unseen data is reported.

# %% [markdown]
# ### Tips for Finalizing Your Model
# This section lists some important considerations when finalizing your machine learning models.
# - **Python Version**. Take note of the Python version. You almost certainly require the
# same major (and maybe minor) version of Python used to serialize the model when you
# later load it and deserialize it.
# - **Library Versions**. The version of all major libraries used in your machine learning
# project almost certainly need to be the same when deserializing a saved model. This is
# not limited to the version of NumPy and the version of scikit-learn.
# - **Manual Serialization**. You might like to manually output the parameters of your
# learned model so that you can use them directly in scikit-learn or another platform in
# the future. Often the techniques used internally by machine learning algorithms to make
# predictions are a lot simpler than those used to learn the parameters can may be easy to
# implement in custom code that you have control over.
#
# Take note of the version so that you can re-create the environment if for some reason you
# cannot reload your model on another machine or another platform at a later time.
#
# We have learned two techniques that we can use:
# - The pickle API for serializing standard Python objects.
# - The Joblib API for efficiently serializing Python objects with NumPy arrays.

# %% [markdown]
# ---
# HOMEWORK: Hyperparameter Optimization and Model Deployment
#
# ---

# %%
# ====================================================================
# HOMEWORK: PRACTICE 10 – IMPROVING PERFORMANCE WITH ALGORITHM TUNING
# ====================================================================

"""
OBJECTIVE:
Systematically improve model performance through parameter optimization
using manual search, grid search, random search, and (optionally) Bayesian
optimization techniques.

NAVAL ENGINEERING CONTEXT:
In real-world ship maintenance systems, model optimization can significantly
improve detection accuracy for corrosion or mechanical degradation events.
Even small improvements in precision can translate into substantial cost
savings and safety benefits.

This homework builds upon previous practices and focuses on the fine-tuning
of machine learning models for better operational reliability.
"""

# ====================================================================
# PART 0: SETUP AND DATA LOADING
# ====================================================================

"""
TASK:
- Load the same dataset used in previous practices (e.g., corrosion_dataset.csv)
- Split data into training and testing sets
- Prepare preprocessing steps if necessary (e.g., scaling, encoding)

HELPFUL HINT:
Use consistent preprocessing across all experiments to ensure fair comparisons.
"""

# # Example
# import pandas as pd
# from sklearn.model_selection import train_test_split

# # Save Model Using joblib
# from pandas import read_csv
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LogisticRegression
# from joblib import dump
# from joblib import load


# filename = '/content/sample_data/Corrosion_Detection_Ships.csv'
# names = ['Years_since_last_inspection',
#               'Water_salinity',
#               'Water_pressure',
#               'Coating_thickness',
#               'Anti_corrosion_concentration',
#               'Hull_material_density',
#               'Inspection_history',
#               'Ship_age',
#               'Hull_Condition']

# # Load dataset (adjust path if necessary)
# df = read_csv(filename, names=names)




# ------------------------------------------------------------

# ====================================================================
# PART 1: MANUAL PARAMETER EXPLORATION
# ====================================================================

"""
TASK:
- Select at least two models (e.g., SVC, RandomForestClassifier)
- Manually adjust hyperparameters and observe performance
- Identify which parameters most influence results

SUGGESTION:
Use small loops to iterate over a few parameter values and record accuracy.
"""

# Example:
# from sklearn.svm import SVC
# from sklearn.metrics import accuracy_score
#
# for c in [0.1, 1, 10]:
#     model = SVC(C=c, kernel='rbf')
#     model.fit(X_train, y_train)
#     preds = model.predict(X_test)
#     print(f"C={c} → Accuracy={accuracy_score(y_test, preds):.3f}")

# ====================================================================
# PART 2: GRID SEARCH OPTIMIZATION
# ====================================================================

"""
TASK:
- Implement GridSearchCV for 2–3 models
- Test multiple scoring metrics (accuracy, F1, ROC-AUC)
- Record best parameters and performance metrics

SUGGESTION:
Use verbose output to track progress and runtime.
"""

# Example:
# from sklearn.model_selection import GridSearchCV
# from sklearn.ensemble import RandomForestClassifier
#
# param_grid = {
#     'n_estimators': [50, 100, 200],
#     'max_depth': [None, 10, 20],
#     'max_features': ['sqrt', 'log2']
# }
#
# grid = GridSearchCV(RandomForestClassifier(), param_grid, cv=5, scoring='accuracy', verbose=2, n_jobs=-1)
# grid.fit(X_train, y_train)
#
# print("Best parameters:", grid.best_params_)
# print("Best score:", grid.best_score_)

# ====================================================================
# PART 3: RANDOM SEARCH OPTIMIZATION
# ====================================================================

"""
TASK:
- Apply RandomizedSearchCV for faster optimization
- Use wide parameter ranges but limit iterations
- Compare runtime and accuracy to GridSearchCV
"""

# Example:
# from sklearn.model_selection import RandomizedSearchCV
# from scipy.stats import randint
#
# random_grid = {
#     'n_estimators': randint(50, 300),
#     'max_depth': randint(5, 30),
#     'min_samples_split': randint(2, 10)
# }
#
# random_search = RandomizedSearchCV(
#     RandomForestClassifier(),
#     random_grid,
#     n_iter=20,
#     cv=5,
#     scoring='f1',
#     random_state=42,
#     n_jobs=-1
# )
# random_search.fit(X_train, y_train)
#
# print("Best parameters:", random_search.best_params_)
# print("Best F1 score:", random_search.best_score_)

# ====================================================================
# PART 4: OPTIONAL – BAYESIAN OPTIMIZATION
# ====================================================================

"""
TASK (Optional Bonus):
- Use Optuna or Scikit-Optimize to perform Bayesian hyperparameter tuning.
- Compare convergence and interpret parameter importance.
"""

# Example (Optuna):
# import optuna
#
# def objective(trial):
#     n_estimators = trial.suggest_int('n_estimators', 50, 200)
#     max_depth = trial.suggest_int('max_depth', 5, 20)
#     model = RandomForestClassifier(
#         n_estimators=n_estimators,
#         max_depth=max_depth,
#         random_state=42
#     )
#     model.fit(X_train, y_train)
#     return model.score(X_test, y_test)
#
# study = optuna.create_study(direction='maximize')
# study.optimize(objective, n_trials=20)
# print("Best parameters:", study.best_params)

# ====================================================================
# PART 5: COMPARATIVE ANALYSIS AND VISUALIZATION
# ====================================================================

"""
TASK:
- Compare all tuning methods (manual, grid, random, bayesian)
- Analyze accuracy, F1-score, and runtime
- Create summary tables and visualizations
"""

# Suggestions:
# - Use pandas DataFrame to store results
# - Plot accuracy vs. search time
# - Use seaborn heatmaps to visualize grid search scores

# ====================================================================
# PART 6: FINAL MODEL EVALUATION
# ====================================================================

"""
TASK:
- Evaluate best-tuned models on the test set
- Compare with default (untuned) versions
- Generate metrics: accuracy, confusion matrix, ROC curve
"""

# Example:
# from sklearn.metrics import classification_report, confusion_matrix
#
# best_model = grid.best_estimator_
# y_pred = best_model.predict(X_test)
#
# print(classification_report(y_test, y_pred))
# print(confusion_matrix(y_test, y_pred))

# ====================================================================
# DELIVERABLES CHECKLIST
# ====================================================================

"""
REQUIRED DELIVERABLES:
□ Correct data loading and preprocessing
□ Manual parameter tuning experiments
□ GridSearchCV and RandomizedSearchCV implementations
□ Comparison of tuning approaches
□ Visualization of parameter effects
□ Final evaluation and discussion

GRADING RUBRIC (100 points):
Implementation Quality (40 pts)
- Grid and random search correctly implemented (20)
- Proper preprocessing and CV setup (10)
- Reproducibility and code quality (10)

Analysis & Interpretation (35 pts)
- Comparison across methods (10)
- Parameter impact analysis (10)
- Visualization and explanation (10)
- Engineering context discussion (5)

Presentation (15 pts)
- Organized notebook structure (5)
- Clean, commented code (5)
- Markdown clarity and insight (5)

Bonus (up to 10 pts)
- Bayesian optimization
- Novel visualization (e.g., parameter sensitivity maps)
- Deep engineering insight

LEARNING OBJECTIVES:
✓ Gain practical experience with hyperparameter tuning
✓ Understand performance–cost tradeoffs
✓ Visualize and interpret tuning outcomes
✓ Connect optimization with engineering impact
✓ Build reproducible, optimized ML pipelines

SUBMISSION:
Submit your notebook as:
[LastName]_[FirstName]_Prac10_Tuning.ipynb
Ensure all cells are executed and outputs are visible.
"""

# ====================================================================
# END OF HOMEWORK DESCRIPTION
# ====================================================================
