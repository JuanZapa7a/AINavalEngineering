# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanZapa7a/AINavalEngineering/blob/main/Prac_08_Machine_Learning_Algorithms%3A_Regresion_Techniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 8: Machine learning algorithms: regresion techniques.
#
# 1.   Elemento de lista
# 2.   Elemento de lista
