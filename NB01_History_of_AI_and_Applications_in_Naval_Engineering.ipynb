# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanZapa7a/AINavalEngineering/blob/main/NB01_History_of_AI_and_Applications_in_Naval_Engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **NB01 · Class 1 — History of Artificial Intelligence and Its Application in Naval Engineering**
#
# ## Block 1: Introduction to AI
#
# ### Learning objectives
#
# By the end of this class, students will be able to:
# - Explain what AI is and place its main historical milestones in context.
# - Distinguish weak AI (*Narrow AI*) from strong AI (*AGI*).
# - Identify real applications of AI in naval and ocean engineering.
# - Set up their own Python/Colab working environment.
# - Interpret a first hands-on example of anomaly detection using ship sensor data.
#
# ### Agenda (2-hour class)
#
# | # | Class segment | Approx. duration | Type |
# |---|---------------------|:---:|:---:|
# | 1 | History of AI (1950 – today) | 45 min | Theory |
# | 2 | AI fundamentals and types of AI (weak/strong) | 25 min | Theory |
# | 3 | Applications of AI in naval engineering | 20 min | Theory |
# | 4 | Setting up the work environment (Python/Colab) | 10 min | Practice |
# | 5 | Hands-on example: engine vibration anomaly detection | 15 min | Practice |
#
# > Timings are approximate guidance, not a strict script — there are no scheduled breaks. If we cover everything with time to spare, class ends early; that can happen and is fine.
#
# ---

# %% [markdown]
# ## Full course roadmap
#
# This course is organized into 4 blocks, aligned with the "Inteligencia Artificial Aplicada" guía docente, and with the real 26-session academic calendar (60 contact hours minus the two written exams and the two individual-project defense sessions the guía docente requires). Every block blends theory and practice within the same class (learning by doing), always using datasets from the naval and ocean engineering domain.
#
# | Block | Content | # of classes |
# |---|---|:---:|
# | **1. Introduction to AI** | History, basic concepts, types of AI, naval applications, work environment | 1 (this class) |
# | **2. AI: Machine Learning** | Scientific Python tooling (NumPy, Matplotlib, SciPy), data curation, classification, regression, clustering, model comparison and tuning | 9 |
# | **3. AI: Deep Learning** | Neural networks, CNNs (vision), RNNs/LSTMs (time series), transfer learning, autoencoders | 7 |
# | **4. Projects: Case Studies** | Real naval and ocean engineering case studies solved end to end | 9 |
#
# > Starting next class we will code in every session: theory will always be paired with a naval dataset so we can practice what was just explained.
#
# ### How this course is graded
#
# | Activity | Weight |
# |---|:---:|
# | Midterm exam 1 (multiple-choice, mid-term) | 20% |
# | Midterm exam 2 (multiple-choice, end of term) | 20% |
# | Individual resolution of a case study already worked through in class | 20% |
# | Individual project + oral defense of a case study **not seen in class** | 40% |
#
# The 40% individual project is `Final_Project_Wave_Height_Forecasting_STARTER.ipynb` (real NOAA ocean buoy data), formally launched in `NB21` — see that notebook for the full grading rubric and defense template.
#
# ---

# %% [markdown]
# ## Part 1 — History of Artificial Intelligence
#
# ### **Definition**
#
# Artificial Intelligence (AI) has evolved significantly since its inception, transforming from theoretical concepts into practical applications that impact almost every aspect of modern life. [Artificial Intelligence (AI)](https://en.wikipedia.org/wiki/Artificial_intelligence) is a branch of [computer science](https://en.wikipedia.org/wiki/Computer_science) that focuses on `creating systems capable of performing tasks that typically require human intelligence`. These tasks include:
#
# - [Problem-solving](https://en.wikipedia.org/wiki/Problem_solving)
# - [Learning from data](https://en.wikipedia.org/wiki/Machine_learning)
# - [Language understanding](https://en.wikipedia.org/wiki/Natural_language_processing)
# - [Perception](https://en.wikipedia.org/wiki/Perception) (e.g., vision or sound)
# - [Decision-making](https://trailhead.salesforce.com/es/content/learn/modules/critical-thinking-and-decision-making-with-data-and-ai/discover-decision-making-frameworks-ai-models)
#
# ### **Importance of AI in Engineering and Other Disciplines**
#
# AI plays a fundamental role in various disciplines beyond computer science. In [engineering](https://en.wikipedia.org/wiki/Engineering), AI enhances [automation](https://en.wikipedia.org/wiki/Automation), [predictive maintenance](https://en.wikipedia.org/wiki/Predictive_maintenance), and [robotics](https://en.wikipedia.org/wiki/Robotics), optimizing industrial processes and improving efficiency. In [medicine](https://en.wikipedia.org/wiki/Artificial_intelligence_in_healthcare), AI assists in disease diagnosis, medical imaging, and personalized treatments. It is also transforming [finance](https://en.wikipedia.org/wiki/Artificial_intelligence_in_finance) through algorithmic trading and risk assessment, while in [education](https://en.wikipedia.org/wiki/Artificial_intelligence_in_education), AI is used for personalized learning and [automated grading systems](https://dl.acm.org/doi/10.1145/3636515).
#
# ### **Brief History of AI**
#
# **[Key Milestones in AI History](https://en.wikipedia.org/wiki/Timeline_of_artificial_intelligence)**
#
# AI has undergone several significant phases, each marked by crucial breakthroughs:
#
# - **[The Birth of AI (1950s–1960s)](https://en.wikipedia.org/wiki/History_of_artificial_intelligence)**: Theoretical foundations laid by pioneers such as [Alan Turing](https://en.wikipedia.org/wiki/Alan_Turing) and the development of the first AI programs.
# - **[The AI Winters (1970s–1980s)](https://en.wikipedia.org/wiki/AI_winter)**: Periods of reduced funding and slow progress due to unmet expectations.
# - **[The Rise of Machine Learning (1990s–2000s)](https://en.wikipedia.org/wiki/Machine_learning)**: The shift from rule-based AI to data-driven approaches.
# - **[The Deep Learning Revolution (2010s–Present)](https://en.wikipedia.org/wiki/Deep_learning)**: Breakthroughs in neural networks leading to advancements in [natural language processing](https://en.wikipedia.org/wiki/Natural_language_processing), [computer vision](https://en.wikipedia.org/wiki/Computer_vision), and [AI-powered automation](https://www.rpatech.ai/ai-powered-automation/).
#
# By examining these milestones, we can better understand how AI has transformed from an abstract idea into a vital technology that continues to shape the future.
#
# | Year | Milestone |
# |------|-----------|
# | **1950** | Alan Turing proposes the "[Turing Test](https://en.wikipedia.org/wiki/Turing_test)" to evaluate machine intelligence. |
# | **1956** | The term *Artificial Intelligence* is coined at the [Dartmouth Conference](https://self-transcendence.org/ai-history-the-dartmouth-conference). |
# | **1960s–70s** | Early AI programs solve math problems and play games like [chess](https://computerhistory.org/blog/ai-and-play-part-1-how-games-have-driven-two-schools-of-ai-research/). |
# | **1980s** | [Expert systems](https://www.techtarget.com/searchenterpriseai/definition/expert-system) become popular (e.g., MYCIN for medical diagnosis). |
# | **1997** | [IBM's Deep Blue](https://www.ibm.com/history/deep-blue) defeats chess world champion Garry Kasparov. |
# | **2012** | Deep Learning revolution begins with breakthroughs in [image recognition](https://www.researchgate.net/publication/385379683_Deep_Learning_in_Image_Recognition_A_New_Era_for_Computer_Vision). |
# | **Today** | AI powers systems in robotics, autonomous ships, [smart assistants](https://aisera.com/chatbots-virtual-assistants-conversational-ai/), and more. |

# %% [markdown]
# ---
#
# ## **The 1950s to 1980s: Initial Optimism and Early Achievements vs "AI Winter"**
#
# Although AI began with high expectations, its early years were marked by both significant achievements and limitations that revealed `the complexity of replicating human intelligence`.
#
# ### **Development of the First AI Programs**
# 1. **[Logic Theorist](https://en.wikipedia.org/wiki/Logic_Theorist?utm_source=chatgpt.com)**: Developed by Allen Newell and Herbert Simon, this program could prove mathematical theorems using logical rules. It marked a milestone by demonstrating machines could perform tasks previously considered exclusive to humans.
# 2. **[General Problem Solver (GPS)](https://en.wikipedia.org/wiki/General_Problem_Solver?utm_source=chatgpt.com)**: An attempt to create a universal program capable of solving any formalized problem. While successful in specific domains, its scope remained limited.
# 3. **[ELIZA](https://en.wikipedia.org/wiki/ELIZA?utm_source=chatgpt.com) and Human Language Simulation**:
#    - Created by [Joseph Weizenbaum](https://en.wikipedia.org/wiki/Joseph_Weizenbaum?utm_source=chatgpt.com) in 1966, ELIZA was one of the first programs to simulate human conversation. Using simple pattern-matching rules, it could hold basic dialogues, particularly in simulated psychological therapy sessions.
#    - Though ELIZA lacked true language comprehension, its ability to [deceive users](https://www.bbc.com/mundo/noticias-44290222?utm_source=chatgpt.com) into believing they were interacting with a human was groundbreaking.
#
# ### **Early Applications of AI**
# - **Games like Checkers and Chess**: AI was applied early to strategy games. In 1948, Alan Turing developed an early chess program, manually simulated but foundational for future research in this [field](https://www.bigdata.uma.es/los-primeros-programas-de-ia-capaces-de-aprender/?utm_source=chatgpt.com).
# - **Expert Systems like [DENDRAL](https://www.britannica.com/technology/DENDRAL?utm_source=chatgpt.com) and [MYCIN](https://www.britannica.com/technology/MYCIN?utm_source=chatgpt.com)**:
#   - **DENDRAL** (1965) helped chemists interpret spectrometric data and hypothesize molecular structures.
#   - **MYCIN** (1970) focused on diagnosing infectious blood diseases, showcasing AI's potential in [medical decision-making](https://blogthinkbig.com/sistemas-expertos-inteligencia-artificial?utm_source=chatgpt.com). [Watch MYCIN in action](https://youtu.be/16Z5hNmfdxQ).
#
# ### **The "AI Winter"**
# - **Challenges**: Early AI systems lacked:
#   1. Autonomous learning capabilities (due to inadequate algorithms).
#   2. Sufficient computational power (limited hardware).
#   3. Access to large datasets (databases were nonexistent).
# - **The Lighthill Report (1973)**: Commissioned by the UK government, this report criticized AI's unfulfilled promises, particularly in areas like [machine translation](https://translatorstudio.co.uk/machine-translation-history/), and highlighted technological limitations. It led to drastic cuts in [UK AI research funding](https://iaresponde.com/invierno-de-la-ia/?utm_source=chatgpt.com). [Watch the 1973 Lighthill Debate](https://youtu.be/03p2CADwGF8).
# - **Impact of the AI Winter**: Interest and funding in AI plummeted during this period. These events underscore the cyclical nature of AI progress, where breakthroughs are often followed by skepticism and reevaluation.
#
# ### **Legacy of the Era**
# The 1950s–1970s laid the groundwork for modern AI, proving `machines could tackle logic, language, and specialized tasks`. Though optimism was tempered by reality, innovations like ELIZA and expert systems paved the way for future advancements in machine learning and neural networks. The lessons from the AI Winter remain relevant, reminding researchers to balance ambition with technical feasibility.

# %% [markdown]
# ---
#
# ## **The 1980s to 2000s: Revival and Consolidation**
#
# ### **The Rise of Expert Systems**
#
# The 1980s marked a pivotal era for artificial intelligence (AI) with the widespread adoption of **[expert systems](https://en.wikipedia.org/wiki/Expert_system)**—rule-based programs designed to emulate human expertise in specialized domains. These systems became the backbone of AI applications in industries such as **medicine, engineering, and business**, revolutionizing decision-making processes.
#
# - In **medicine**, systems like **[MYCIN](https://en.wikipedia.org/wiki/Mycin)** and **[DXplain](https://en.wikipedia.org/wiki/DXplain)** demonstrated the potential of ***AI in diagnostics***. ***MYCIN***, developed at ***Stanford University***, could ***identify bacterial infections and recommend antibiotics*** with 65-70% accuracy, rivaling human specialists. Similarly, ***DXplain*** used ***a knowledge base of diseases to suggest diagnoses based on symptoms***. These tools reduced errors and streamlined workflows in healthcare.
# - In **engineering**, expert systems like **[XCON](https://en.wikipedia.org/wiki/XCON)** (developed by Digital Equipment Corporation) ***optimized manufacturing processes by configuring computer components automatically***. Meanwhile, **[PROSPECTOR](https://en.wikipedia.org/wiki/Prospector_%28expert_system%29)** ***aided geologists in mineral exploration***, identifying promising mining sites with 85% accuracy. These applications underscored AI's ability to handle complex, domain-specific problems.
# - The **business sector** embraced systems like **[CLIPS](https://en.wikipedia.org/wiki/CLIPS)** for tasks ranging from ***fraud detection to financial forecasting***. Banks used AI to assess credit risks, while retailers leveraged it for inventory management. By the late 1980s, the global expert systems market was valued at over $1 billion.
#
# However, **limitations** soon emerged. Expert systems relied on **manual rule creation**, requiring labor-intensive input from human experts—a bottleneck known as the **[knowledge acquisition problem](https://en.wikipedia.org/wiki/Knowledge_engineering)**. They also struggled with adaptability; unlike humans, they ***couldn't learn from new data or handle ambiguous scenarios***. Critics argued that these systems were merely "frozen knowledge," incapable of evolving. By the 1990s, the hype around expert systems waned, though their legacy influenced later AI developments.
#
# ### **Advancements in Algorithms and Hardware**
#
# While expert systems dominated applications, breakthroughs in **algorithms** and **hardware** laid the groundwork for modern AI. Central to this progress was the resurgence of **[artificial neural networks](https://en.wikipedia.org/wiki/Artificial_neural_network)** (ANNs), inspired by the human brain's structure.
#
# - In 1986, the **[backpropagation algorithm](https://en.wikipedia.org/wiki/Backpropagation)**—pioneered by researchers like **[Geoffrey Hinton](https://en.wikipedia.org/wiki/Geoffrey_Hinton)**—revolutionized neural network training. Backpropagation allowed networks to adjust their internal parameters by propagating errors backward through layers, enabling them to learn from mistakes. This innovation led to multi-layer networks ***capable of solving non-linear problems, such as image recognition and speech processing***.
# - The era also saw theoretical strides in **[deep learning](https://en.wikipedia.org/wiki/Deep_learning)**. In 1989, [Yann LeCun](https://scholar.google.com/citations?user=WLN3QrAAAAAJ&hl=es) demonstrated the **[LeNet](https://en.wikipedia.org/wiki/LeNet)** architecture, a convolutional neural network (CNN) that could [recognize handwritten digits](https://www.geeksforgeeks.org/machine-learning/handwritten-digit-recognition-using-neural-network/). Though limited by computational power, these early models proved the viability of deep learning. Researchers like **[Jürgen Schmidhuber](https://en.wikipedia.org/wiki/Jürgen_Schmidhuber)** explored **[recurrent neural networks](https://en.wikipedia.org/wiki/Recurrent_neural_network)** (RNNs), which processed sequential data—a precursor to today's language models.
# - Hardware advancements further accelerated AI. The rise of **[parallel processing](https://en.wikipedia.org/wiki/Parallel_computing)** and specialized chips, like **[GPUs](https://en.wikipedia.org/wiki/Graphics_processing_unit)**, allowed faster computations. By the 1990s, projects like **[Connection Machine](https://en.wikipedia.org/wiki/Connection_Machine)** demonstrated how massive parallelism could tackle AI tasks. These innovations, though underappreciated at the time, set the stage for 21st-century breakthroughs.
#
# ### **Major Milestones**
#
# Two landmark achievements in the 1990s symbolized AI's growing prowess: **chess mastery** and **autonomous vehicles**.
#
# - In 1997, IBM's **[Deep Blue](https://en.wikipedia.org/wiki/Deep_Blue_%28chess_computer%29)** defeated world champion [Garry Kasparov](https://en.wikipedia.org/wiki/Garry_Kasparov) in a six-game match. `Deep Blue combined brute-force computation (evaluating 200 million positions per second) with strategic heuristics`, showcasing AI's ability to outperform humans in rule-based domains.
# - Meanwhile, projects like **[ALVINN](https://en.wikipedia.org/wiki/ALVINN)** (Autonomous Land Vehicle in a Neural Network) pioneered self-driving technology. Developed at Carnegie Mellon University in 1989, ALVINN used a neural network to process camera inputs and steer a vehicle. By 1995, CMU's **[NavLab 5](https://en.wikipedia.org/wiki/Navlab)** completed a 2,800-mile "No Hands Across America" journey, with the system controlling 98% of the steering. These efforts laid the foundation for companies like **[Waymo](https://en.wikipedia.org/wiki/Waymo)** and **[Tesla](https://en.wikipedia.org/wiki/Tesla,_Inc.)**.
# - Other milestones included **[TD-Gammon](https://en.wikipedia.org/wiki/TD-Gammon)** (1992), a self-taught backgammon program, and **[RAVL](https://en.wikipedia.org/wiki/Active_appearance_model)** (1996), an early facial recognition system. Though these technologies were nascent, they hinted at AI's future potential in gaming, robotics, and biometrics.
#
# ### **Legacy of the Era**
#
# The 1980s–1990s transformed AI from an academic curiosity into a tool with real-world impact. While expert systems faced decline, they popularized AI in industries and inspired later **[knowledge-based systems](https://en.wikipedia.org/wiki/Knowledge-based_systems)**. Advances in neural networks and hardware, though initially niche, became the bedrock of 21st-century innovations like **[AlphaGo](https://en.wikipedia.org/wiki/AlphaGo)** and modern language models. This era's lessons—balancing ambition with practicality—continue to shape AI's evolution today.

# %% [markdown]
# ---
#
# ## **The 21st Century: The Era of Big Data and Deep Learning**
#
# The 21st century has witnessed an unprecedented explosion of [data](https://en.wikipedia.org/wiki/Data) and [computational power](https://en.wikipedia.org/wiki/Computational_power), fueling advancements in [artificial intelligence (AI)](https://en.wikipedia.org/wiki/Artificial_intelligence). With the proliferation of [digital technologies](https://en.wikipedia.org/wiki/Digital_technology), the availability of vast [datasets](https://en.wikipedia.org/wiki/Data_set), and the refinement of [machine learning](https://en.wikipedia.org/wiki/Machine_learning) techniques, AI has become an integral part of modern life. This era has been largely defined by two key components: **[big data](https://en.wikipedia.org/wiki/Big_data)** and **[deep learning](https://en.wikipedia.org/wiki/Deep_learning)**, both of which have significantly shaped the development and application of AI across various domains.
#
# ### **The Role of Big Data**
#
# One of the defining characteristics of contemporary AI is the vast amount of [data](https://en.wikipedia.org/wiki/Data) available for training machine learning models. The rise of the [internet](https://en.wikipedia.org/wiki/Internet), [social media](https://en.wikipedia.org/wiki/Social_media), and [connected devices](https://en.wikipedia.org/wiki/Internet_of_things) has resulted in an exponential increase in the amount of structured and unstructured data. This data explosion has been instrumental in the advancement of AI for several reasons:
#
# 1. **[Improved Model Training](https://en.wikipedia.org/wiki/Training_data)**: The availability of large datasets allows AI systems to be trained on diverse examples, improving their accuracy and generalization.
# 2. **[Data-Informed Decision Making](https://en.wikipedia.org/wiki/Data-informed_decision-making)**: AI models can analyze massive amounts of data to derive insights, helping businesses, governments, and researchers make informed decisions.
# 3. **[Personalized Experiences](https://en.wikipedia.org/wiki/Personalization)**: From recommendation systems on streaming platforms to targeted advertising, big data enables AI to create personalized experiences for users.
#
# #### **Applications of Big Data in AI**
#
# - **[Image Recognition](https://en.wikipedia.org/wiki/Image_recognition)**: Large-scale datasets such as [ImageNet](https://en.wikipedia.org/wiki/ImageNet) have fueled breakthroughs in [computer vision](https://en.wikipedia.org/wiki/Computer_vision), enabling applications like [facial recognition](https://en.wikipedia.org/wiki/Facial_recognition_system), [autonomous vehicles](https://en.wikipedia.org/wiki/Self-driving_car), and [medical imaging](https://en.wikipedia.org/wiki/Medical_imaging).
# - **[Natural Language Processing (NLP)](https://en.wikipedia.org/wiki/Natural_language_processing)**: AI-powered NLP systems rely on massive text corpora to improve language understanding, powering applications such as [chatbots](https://en.wikipedia.org/wiki/Chatbot), [virtual assistants](https://en.wikipedia.org/wiki/Virtual_assistant), and [automated translation services](https://en.wikipedia.org/wiki/Machine_translation).
# - **[Recommendation Systems](https://en.wikipedia.org/wiki/Recommender_system)**: AI leverages big data to analyze user preferences and provide personalized recommendations in [e-commerce](https://en.wikipedia.org/wiki/E-commerce), [entertainment](https://en.wikipedia.org/wiki/Streaming_media), and [news](https://en.wikipedia.org/wiki/Online_news).
#
# ### **Deep Learning: A Revolutionary Approach**
#
# [Deep learning](https://en.wikipedia.org/wiki/Deep_learning), a subset of [machine learning](https://en.wikipedia.org/wiki/Machine_learning), has emerged as the `dominant approach in AI research and applications`. It involves training [artificial neural networks](https://en.wikipedia.org/wiki/Artificial_neural_network) with `multiple layers (deep networks)` to identify patterns in data. Unlike traditional machine learning techniques, `deep learning models automatically extract features from raw data, eliminating the need for extensive manual feature engineering`.
#
# #### **Pioneers of Deep Learning**
#
# Three researchers—[Geoffrey Hinton](https://en.wikipedia.org/wiki/Geoffrey_Hinton), [Yann LeCun](https://en.wikipedia.org/wiki/Yann_LeCun), and [Yoshua Bengio](https://en.wikipedia.org/wiki/Yoshua_Bengio)—are widely regarded as the pioneers of deep learning. Their contributions have been instrumental in shaping the field:
#
# - **[Geoffrey Hinton](https://en.wikipedia.org/wiki/Geoffrey_Hinton)**: Developed [backpropagation](https://en.wikipedia.org/wiki/Backpropagation) techniques for training deep neural networks and played a key role in advancing [deep belief networks](https://en.wikipedia.org/wiki/Deep_belief_network).
# - **[Yann LeCun](https://en.wikipedia.org/wiki/Yann_LeCun)**: Introduced [convolutional neural networks (CNNs)](https://en.wikipedia.org/wiki/Convolutional_neural_network), revolutionizing image recognition and [computer vision](https://en.wikipedia.org/wiki/Computer_vision).
# - **[Yoshua Bengio](https://en.wikipedia.org/wiki/Yoshua_Bengio)**: Contributed significantly to [sequence modeling](https://en.wikipedia.org/wiki/Sequence_learning) and deep learning optimization techniques.
#
# #### **Advancements in Neural Networks**
#
# - **[Convolutional Neural Networks (CNNs)](https://en.wikipedia.org/wiki/Convolutional_neural_network)**: These networks specialize in image and video analysis by detecting spatial hierarchies in data. CNNs have been instrumental in developing AI applications in [facial recognition](https://en.wikipedia.org/wiki/Facial_recognition_system), [medical diagnostics](https://en.wikipedia.org/wiki/Medical_diagnosis), and [autonomous vehicles](https://en.wikipedia.org/wiki/Self-driving_car).
# - **[Recurrent Neural Networks (RNNs)](https://en.wikipedia.org/wiki/Recurrent_neural_network)**: Unlike traditional neural networks, RNNs can process sequential data, making them ideal for applications like [speech recognition](https://en.wikipedia.org/wiki/Speech_recognition) and [language modeling](https://en.wikipedia.org/wiki/Language_model).
#
# | Architecture | Specialty | Naval use-case example |
# |---|---|---|
# | **CNN** (Convolutional Neural Network) | Images and video | Visual hull inspection, corrosion detection |
# | **RNN / LSTM** (Recurrent Neural Network) | Sequential data / time series | Predictive maintenance from vibration sensors |
# | **Generative networks (GANs)** | Synthetic data generation | Generating synthetic naval sensor data when real data is scarce |
#
# ### **Recent Milestones in AI**
#
# - **[AlphaGo's Historic Victory (2016)](https://en.wikipedia.org/wiki/AlphaGo_versus_Lee_Sedol)**: One of the most significant AI milestones was the victory of **[AlphaGo](https://en.wikipedia.org/wiki/AlphaGo)**, a deep learning-based program developed by [DeepMind](https://en.wikipedia.org/wiki/DeepMind), over South Korean [Go](https://en.wikipedia.org/wiki/Go_%28game%29) champion [Lee Sedol](https://en.wikipedia.org/wiki/Lee_Sedol) in 2016.
# - **The Rise of Large Language Models**: Language models such as GPT-3 and its successors have redefined the capabilities of AI in understanding and generating human-like text.
# - **[Applications of artificial intelligence](https://en.wikipedia.org/wiki/Applications_of_artificial_intelligence#Finance)**: AI has also made significant strides in real-world applications across multiple industries.

# %% [markdown]
# ---
#
# ### Recommended reading (outside class)
#
# - **The future of AI**: Explainable AI (XAI) and AI ethics, quantum computing applied to AI, integration with IoT and robotics — see this [guide to the future of AI](https://www.techtarget.com/searchenterpriseai/tip/The-future-of-AI-What-to-expect-in-the-next-5-years).
# - **Challenges**: impact on employment, data privacy, AI regulation.
# - **Core course bibliography**:
#   1. Russell, S. (2021). *Artificial Intelligence: a Modern Approach*. Pearson.
#   2. Johansson, R. *Numerical Python: A Practical Techniques Approach with Examples in Python*. Apress.
#   3. Hill, C. (2020). *Learning Scientific Programming with Python*. Cambridge University Press.
# - **Online resources**: [arXiv](https://arxiv.org/), [Google Scholar](https://scholar.google.com/), [Towards Data Science](https://towardsdatascience.com/).

# %% [markdown]
# ## Part 2 — AI Fundamentals and Applications in Naval Engineering
#
# In this part, we will introduce the fundamental concepts of **[Artificial Intelligence (AI)](https://en.wikipedia.org/wiki/Artificial_intelligence)** and its relevance in the field of [**naval engineering**](https://www.nrl.navy.mil/Our-Work/Areas-of-Research/Artificial-Intelligence/):
# - **Basic Concepts of AI**
# - **Types of AI: Weak vs Strong AI**
# - **General Applications of AI in Naval Engineering**
# - **AI Work Environment**
# - **Examples of applications**
#
# ### **Basic Concepts of AI**
#
# Artificial intelligence (AI) is a field of computer science focused on developing systems capable of performing tasks that typically require human intelligence, such as learning, reasoning, problem-solving, perception, and decision-making. It encompasses various subfields and technologies, including machine learning, deep learning, natural language processing, computer vision, and robotics, which work together to `enable machines to learn from data, adapt to new situations, and improve their performance over time`.
#
# 1. **[Machine Learning (ML)](https://en.wikipedia.org/wiki/Machine_learning)**: A core subset of AI where systems learn from data without being explicitly programmed. It involves algorithms that identify patterns in data to make predictions or decisions. ML is categorized into supervised learning (using labeled data), unsupervised learning (finding patterns in unlabeled data), semi-supervised learning (a mix of both), and reinforcement learning (learning through trial and error with rewards and penalties).
#    Example: [Predicting equipment failures based on sensor data](https://spd.tech/machine-learning/predictive-maintenance/).
#
# 2. **[Deep Learning (DL)](https://en.wikipedia.org/wiki/Deep_learning)**: A subfield of machine learning that uses artificial neural networks with multiple layers to process complex data like images, audio, and text. It mimics the human brain's structure and can automatically learn relevant features from raw data, improving accuracy over time.
#    Example: [Automated topology design to improve the susceptibility of naval ships using geometric deep learning](https://academic.oup.com/jcde/article/10/2/794/7084993?login=false).
#
# 3. **[Artificial Neural Networks (ANNs)](https://en.wikipedia.org/wiki/Artificial_neural_network)**: Computational models inspired by the human brain, composed of interconnected nodes (neurons) organized in layers (input, hidden, output). They process information by adjusting weights and thresholds, enabling the system to learn and make predictions.
#    Example: [Autonomous navigation systems for ships](https://promwad.com/news/navigation-systems-autonomous-ships).
#
# 4. **[Natural Language Processing (NLP)](https://en.wikipedia.org/wiki/Natural_language_processing)**: A branch of AI that enables machines to understand, interpret, and generate human language. It powers applications like voice assistants, translation services, and chatbots by analyzing grammar, context, and meaning in text and speech.
#    Example: [Voice-controlled systems for ship operations](https://www.asti-usa.com/progexs/military/naval_comms.html).
#
# 5. **[Generative AI](https://en.wikipedia.org/wiki/Generative_artificial_intelligence)**: An application of AI that creates new, original content such as text, images, audio, video, and code by identifying patterns in large datasets. It is driven by large language models (LLMs) and foundation models trained on vast amounts of data, allowing them to produce outputs based on user prompts.
#    Example: [Generative AI in naval engineering: Small, proprietary data sets limit adoption](https://www.zdnet.com/article/generative-ai-in-naval-architecture-and-marine-engineering-small-proprietary-data-sets-limit-adoption/).
#
# 6. **[AI Agents](https://github.com/resources/articles/ai/what-are-ai-agents)**: Entities that perceive their environment and take actions to achieve goals. They can be classified as assisted (helping humans), augmented (enhancing human abilities), or autonomous (operating independently without human intervention).
#    Example: [Revolutionising Ship Design with Artificial Intelligence and Machine Learning](https://www.bmt.org/insights/revolutionising-ship-design-with-artificial-intelligence-and-machine-learning/).
#
# ### **Types of AI: Weak vs Strong AI**
#
# Artificial Intelligence (AI) is broadly categorized into two main types: [Weak AI and Strong AI](https://www.geeksforgeeks.org/artificial-intelligence/what-is-the-difference-between-a-strong-ai-and-a-weak-ai/), representing distinct capabilities and levels of intelligence.
#
# | Feature | **Weak AI** | **Strong AI** |
# |----------------------|--------------------------------|------------------------------------|
# | Scope | Narrow, task-specific | Broad, general-purpose |
# | Consciousness | No | Theoretical, Yes |
# | Human-level thinking | No | Yes |
# | Examples | Siri, Google Translate, spam filters | HAL 9000, Data (*fictional*) |
# | Learning & Adapting | Limited | Flexible and self-improving |
#
# | Type | Description | Maritime Perspective |
# |------|-------------|----------------------|
# | Weak AI (Narrow AI) | Specialized in one task. Cannot generalize beyond it. | Autopilot system, navigation assistant. |
# | Strong AI (General AI) | Human-level intelligence, flexible and adaptable. | Hypothetical - a fully autonomous ship able to make decisions like a captain in all scenarios. |
#
# > **Key Insight**: Most of today's AI systems — including everything we'll build in this course — are **Weak AI**. Strong AI remains theoretical and is still an open research challenge.

# %% [markdown]
# ### **Applications of AI in Naval Engineering**
#
# AI is transforming naval engineering by `enhancing efficiency, safety, and sustainability`. Artificial intelligence (AI) is increasingly being integrated into naval engineering, transforming design, maintenance, and operational capabilities. Below are some key applications:
#
# 1. **Automation**:
#    - AI enables the development of autonomous systems for ships, such as self-navigating vessels and automated control systems.
#    - Example: **[Autonomous Ships](https://www.imo.org/en/MediaCentre/HotTopics/Pages/Autonomous-shipping.aspx)** use AI to navigate, avoid obstacles, and optimize routes without human intervention.
#
# 2. **Predictive Maintenance**:
#    - AI models analyze data from sensors and equipment to predict potential failures before they occur. This reduces downtime and maintenance costs.
#    - Example: Using **[Machine Learning](https://towardsdatascience.com/predictive-maintenance-using-machine-learning-2b8d6b02e5a4)** to monitor engine performance and detect anomalies in real-time.
#
# 3. **Route Optimization**:
#    - AI algorithms optimize shipping routes by considering factors like weather conditions, fuel consumption, and delivery schedules.
#    - Example: **[AI-powered route planning](https://www.ibm.com/blogs/internet-of-things/iot-maritime-route-optimization/)** minimizes fuel usage and reduces environmental impact.
#
# 4. **Data Analysis**:
#    - Ships generate vast amounts of data from sensors, navigation systems, and operational logs. AI processes this data to provide actionable insights.
#    - Example: Real-time monitoring of ship performance using **[Big Data Analytics](https://www.sciencedirect.com/topics/engineering/big-data-analytics)**.
#
# 5. **Generative AI in Ship Design**:
#    - Generative AI in ship design systems use machine learning to predict hull performance, such as resistance, in real-time, reducing reliance on computationally intensive simulations.
#    - Example: Tools like [Compute Maritime's NeuralShipper](https://www.computemaritime.com/) and [BMT's AI-driven approaches](https://www.bmt.org/insights/revolutionising-ship-design-with-artificial-intelligence-and-machine-learning/) are enabling the rapid generation and evaluation of hundreds of design variations, significantly accelerating the preliminary design phase. [Austal's DeepMorpher](https://web.archive.org/web/20251008034033/https://www.austal.com/news/austal%E2%80%99s-new-artificial-intelligence-toolset-%E2%80%98deepmorpher%E2%80%99-enhances-rapid-digital-prototyping) tool leverages a large proprietary library of hull forms.
#
# 6. **Autonomous Systems and Communication**:
#    - Systems that allow interaction with crewed platforms using human-like language, addressing a critical operational challenge in maritime autonomy and improving coordination in complex environments.
#    - Example: The [UK's Defence and Security Accelerator (DASA)](https://oecd-opsi.org/innovations/the-defence-and-security-accelerator-dasa/) is funding trials for natural language communication systems on [uncrewed surface vessels (USVs)](https://oceanexplorer.noaa.gov/technology/usv/).
#
# 7. **Industry Collaboration and Digital Transformation**:
#    - Strategic partnerships are focused on creating AI applications for ship layout design, aiming to reduce development costs and timelines.
#    - Example: [DessIA and Naval Group](https://www.nafems.org/about-us/media/news/industrynews1003/dessia-technologies-and-naval-group-sign-a-memorandum-of-understanding-/) signed a unified digital thread connecting design, construction, and in-service support data through a common digital environment.

# %% [markdown]
# ### **Setting Up the Work Environment**
#
# To begin working on AI projects, you need to configure a development environment with the following tools:
#
# 1. **[Python](https://www.python.org/)**: Python is the most widely used programming language in AI due to its simplicity and extensive libraries.
# 2. **[Jupyter Notebooks](https://jupyter.org/)** (or **[Google Colab](https://colab.research.google.com/)**, which we'll use throughout this course): they provide an interactive environment for writing and executing code.
# 3. **Essential Libraries**:
#    - **[NumPy](https://numpy.org/)**: A library for numerical computations and handling arrays.
#    - **[Pandas](https://pandas.pydata.org/)**: A library for data manipulation and analysis.
#      - Load the dataset: `import pandas as pd; data = pd.read_csv('sensor_data.csv')`.
#      - Explore the data: `data.head()`, `data.describe()`.
#    - **[Matplotlib](https://matplotlib.org/)**: A library for creating visualizations and plots.
#      - `import matplotlib.pyplot as plt; plt.plot(data['timestamp'], data['sensor_value'])`.
#    - Installation (not needed on Colab, which already includes them): `pip install numpy pandas matplotlib`.
#
# **Expected Outcomes**: by the end of this class, students will understand the basic concepts of AI and its applications in naval engineering, have a functional AI development environment set up, and be able to perform basic data analysis and visualization using Python. This theoretical and practical foundation will prepare students for the more advanced AI techniques covered in upcoming classes, focused on solving real-world naval engineering challenges.

# %% [markdown]
# ---
# ### **Hands-on example: Predicting Failures due to Engine Vibrations**
#
# Let's simulate a simplified predictive-maintenance case: an engine vibration sensor on a ship, recording data every hour over one day.
#
# > **Further reading**: [Anomaly detection (Wikipedia)](https://en.wikipedia.org/wiki/Anomaly_detection) · [Vibration (Wikipedia)](https://en.wikipedia.org/wiki/Vibration).

# %%
# Let's Visualize a Use Case
import matplotlib.pyplot as plt
import numpy as np

# Simulated engine vibration data
np.random.seed(0)
hours = np.arange(0, 24, 1)
vibration = 0.3 * np.sin(0.3 * hours) + np.random.normal(0, 0.1, size=hours.shape)

plt.figure(figsize=(10, 4))
plt.plot(hours, vibration, marker='o')
plt.title("Simulated Engine Vibration Over 24 Hours")
plt.xlabel("Time (hours)")
plt.ylabel("Vibration Amplitude")
plt.grid(True)
plt.show()

# %% [markdown]
# If we label when vibration goes above a threshold, AI can learn to predict failures in advance.

# %%
thresh = 0.25
alerts = vibration > thresh

plt.figure(figsize=(10, 4))
plt.plot(hours, vibration, label="Vibration")
plt.axhline(thresh, color='red', linestyle='--', label="Threshold")
plt.scatter(hours[alerts], vibration[alerts], color='red', label="Alerts")
plt.title("Predictive Maintenance Threshold")
plt.xlabel("Time (hours)")
plt.ylabel("Vibration Amplitude")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# ### Preview: the naval datasets we'll use in this course
#
# Starting next class we'll always work with real or naval/ocean-engineering-adapted data. Here's a preview:
#
# | Dataset | Origin | Used in |
# |---|---|---|
# | `Naval_Dataset.csv` / `2` / `3` | Synthetic (ship dimensions and type) | Python fundamentals, clustering |
# | `ship_fuel_efficiency.csv` | Fuel consumption per route | Visualization, case study (Block 4) |
# | `yacht_hydrodynamics.data` | Real (UCI ML Repository) | SciPy, regression |
# | `sonar.all-data` (mines vs. rocks) | Real (UCI ML Repository) | Classification |
# | `Naval_Maintenance_Dataset.csv` | Synthetic (maintenance cost) | Classic regression and first neural network (Block 3) |
# | LIACi (underwater hull inspection) | Real (academic dataset) | CNN — computer vision (Block 3) |
# | ECMWF / CLIWOC / GMTED | Real (Copernicus, historical logs, USGS) | Case studies (Block 4) |

# %% [markdown]
# ---
# ## Class summary
#
# - AI has gone from theory (Turing, 1950) to transforming today's naval engineering: predictive maintenance, autonomous navigation, route optimization, and generative ship design.
# - Almost all AI applied today — including everything in this course — is **Weak AI**: systems specialized in one specific task.
# - We now have our work environment ready (Python + Colab + NumPy/Pandas/Matplotlib) and saw a first example of anomaly detection with sensor data.
#
# ## For the next class (NB02)
#
# We'll start Block 2 (Machine Learning): scientific Python foundations and a first hands-on contact with a real naval dataset using Pandas.
#
# ## Homework / Practice Ideas
#
# 1. Simulate your own sensor (e.g., water temperature, pressure).
# 2. Use matplotlib to plot your data.
# 3. Identify potential anomalies or thresholds visually.
# 4. Write text cells explaining your procedure.
# 5. You may use an AI assistant to help develop this task.
#
# > ***Try to relate everything to marine operations or ship systems!***
